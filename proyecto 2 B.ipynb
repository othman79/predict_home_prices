# %% [markdown]
# ![image.png](attachment:56fce5ce-7b48-45b2-b095-9ab63c5debec.png)

# %% [markdown]
# # Resumen del proyecto
# Aplica transformación de datos y entrena Modelos Avanzados para desarrollar con mayor profundidad tu modelo de Machine Learning. ¿Qué puedes aprender del problema que estás abordando mediante el estudio de tu propio modelo?
#
# La realización y entrega del Proyecto es individual.
#
# # Entregable
# Un Notebook de Jupyter con la resolución de la consigna. El Notebook debe poder ejecutarse sin errores.
#
# # Referencias
# Apóyate en las bitácoras, los notebooks trabajados y las presentaciones vistas en clase para resolver tu proyecto. También será de mucha utilidad la documentación de las librerías de Python. No dudes en consultar comunidades online como Stack Overflow y, por supuesto, buscar en la web (googlear).
#
# # Recursos
# Para realizar el proyecto:
#
# Utiliza el siguiente dataset (es el mismo que en el Proyecto 01): Dataset Properati (DSProyecto01DatosProperati.csv)
# Retoma el notebook desarrollado para el Proyecto 01 y considera la devolución que recibiste de tu evaluador/a.
# # Consigna
# En este proyecto profundizarás lo desarrollado en el proyecto 01 (“Primer modelo de Machine Learning”). El objetivo es aplicar las técnicas incorporadas (Transformación de Datos, Optimización de Hiperparámetros, Modelos Avanzados, etc.) para generar un modelo que tenga un mejor desempeño que el modelo generado en el proyecto anterior. Luego, interpreta ese modelo para responder la siguiente pregunta: ¿qué podemos aprender de nuestro problema estudiando el modelo que generamos?
#
# El trabajo se organiza en tres partes:
#
# ## PARTE A - Transformación de Datos
#
# Elige cuáles de las siguientes tareas son apropiadas para su dataset. Implementa las transformaciones que elegiste. Es importante que justifiques por qué las haces:
#
# Detección y eliminación de Outliers
# Encoding
# Imputación de valores faltantes
# Escalado de datos
# Generación de nuevas variables predictoras/reducción de dimensionalidad (SVD/PCA).
# Vuelve a entrenar el modelo implementado en la Entrega 01 - en particular, el árbol de decisión - con este nuevo dataset transformado. Evalúa su desempeño a partir del dataset obtenido luego de transformar los datos. ¿Hay una mejora en su desempeño? Compara con el desempeño obtenido en el proyecto 01. Sea cual sea la respuesta, intenta explicar a qué se debe.
#
# ## PARTE B - Modelos Avanzados
#
# Elige dos de los modelos avanzados vistos Compara con el desempeño obtenido en el proyecto 01 (en el caso de regresión, considera una regresión lineal con atributos polinómicos y regularización). Entrénalos y evalúalos con sus argumentos por defecto. No te olvides de hacer un train/test split y usar Validación Cruzada.
# Optimiza sus hiperparámetros mediante Validación Cruzada y Grid Search o Random Search.
# Compara el desempeño de los nuevos modelos entre sí y con el modelo de la Parte A. ¿Cuál elegirías? Justifica.
# ## PARTE C - Interpretación de modelos
#
# De acuerdo a lo que el modelo permite, responde algunas o todas las siguientes preguntas:
#
# ¿Qué variables fueron relevantes para el modelo para hacer una predicción? ¿Cuáles no? Si usaste una regresión lineal con regularización, presta atención a los parámetros (pendientes) obtenidas. Si usaste un modelo de ensamble en árboles, además de ver la importancia de cada atributo, también elige algunos árboles al azar y observa qué atributos considera importantes. ¿En qué se diferencian esos árboles? ¿Por qué? Finalmente, responde, ¿coincide con lo que esperabas a partir de tu experiencia con este dataset?
# ¿Cómo es la distribución de errores (regresión) o qué clases se confunden entre sí (clasificación)? ¿Dónde falla? ¿A qué se debe?
#
# ## DESAFÍO OPCIONAL
#
# Aplica una técnica de Clustering sobre el dataset. Puedes combinar con técnicas de reducción de dimensionalidad para facilitar la visualización. ¿Qué clusters encuentras? ¿A qué pueden corresponder? Te dejamos preguntas que pueden servir como disparadoras: ¿qué barrios se parecen más entre sí?¿qué tipos de propiedades se parecen más entre sí?
#
# ## Checklist de evaluación
# Sugerencias para desarrollar el proyecto:
#
# Este proyecto no cuenta con mínimos entregables indicados en la consigna, pero ten en cuenta lo siguiente:
# en la Parte A debes implementar al menos tres de las transformaciones de datos propuestas.
# en la Parte B, al menos un modelo debe ser optimizado por Grid Search o Random Search; el otro puede ser optimizado por búsqueda manual (es decir, puedes dejar los mejores parámetros que encontraste probando).
# en la Parte C, debes responder al menos una pregunta. Obviamente, ¡cuanto más hagas, más aprenderás y mejor será tu proyecto!
# La resolución del proyecto te puede enfrentar a pequeños desafíos que no trabajamos durante los encuentros. Es importante que desarrolles la capacidad de resolverlos. Para ello, consulta las bitácoras, las referencias, los notebooks vistos en clase, la documentación de la librería y, sobre todo, googlea.
# Antes de subir tu proyecto a la plataforma Acámica para que sea evaluado, verifica que el Notebook se ejecute sin errores. Además, asegúrate de cumplir con las siguientes condiciones (son las que los/as evaluadores/as tendrán en consideración al momento de corregir tu trabajo):
#
# ## PARTE A - Transformación de Datos
#
# Debes justificar por qué creés que las transformaciones elegidas aplican en este dataset. Ten en cuenta que, en el manejo de valores atípicos o en la imputación de valores faltantes, los valores obtenidos deben tener sentido. Por ejemplo, valores mayores que cero para superficies, número de baños, etc.
# Debes re entrenar un modelo del Proyecto 01 y comparar su desempeño con el modelo obtenido en el Proyecto 01. Una aclaración: con reentrenar nos referimos a usar el mismo proceso de entrenamiento junto con sus hiperparámetros. Pero puede ocurrir - y, de hecho, se espera - que el dataset contenga más atributos que los utilizados en el Proyecto 01.
# ## PARTE B - Modelos Avanzados
#
# En la optimización de hiperparámetros, debes justificar los parámetros que elegiste para optimizar y el rango de cada uno.
# ## PARTE C - Interpretación de modelos
#
# Debes estudiar qué variables utiliza el modelo para predecir y responder la pregunta: ¿coincide con lo que esperabas a partir de tu experiencia con este dataset?
# Es muy importante que analices los errores del modelo. ¿Dónde es mayor el error? ¿dónde acierta?
# Debes ser crítico/a con la metodología utilizada. ¿Qué mejorarías? Ten en cuenta siempre terminar con una discusión sobre lo realizado y conclusiones obtenidas.

# %% [markdown]
# # <div align="center">Referencia del Proyecto</div>
#
# #### La información de nuestro primer modelo Benchmark, realizado con vecinos mas cercanos, nos dio los siguientes valores:
#
#      * El modelo inicialmente fue completado realizar con 3 variables 'surface_total', 'bathrooms', 'surface_covered'.
#
#      * La Raíz del error cuadrático medio en Train:  $ 132.897.
#  * La Raíz del error cuadrático medio en Test:   $ 157.394.
#
#
# #### Con hiperparámetro y una profundidad del modelo de 10 y cambiando el modelo al el algoritmo de árboles de decisiónes, logramos:
#
#      * Este nuevo modelo fue Realizado con 4 variables 'bathrooms', 'surface_covered', 'rooms', 'bedrooms' y descartamos a 'surface_total'.
#
#      * La Raíz del error cuadrático medio en Train:   $ 129.082.
#  * La Raíz del error cuadrático medio en Test :   $ 150.734.

# %% [markdown]
# # <div align="center">Librerías</div>
# <div align="center">
# <img src="https://image.freepik.com/foto-gratis/resumen-desenfoque-defocused-biblioteca-tienda-libros-tienda-interior_1203-9330.jpg" alt="drawing" style="width:1000px;height: 400px"/></div>
#
# Las librerías que vamos a utilizar son:

# %%
# Tratamiento de datos
# ==============================================================================
import numpy as np
import pandas as pd
from pandas import get_dummies

# Gráficos
# ==============================================================================
import matplotlib.pyplot as plt
from matplotlib import style
import seaborn as sns
import missingno as msno
from IPython.display import display
pd.options.display.max_columns = None


# Preprocesado y modelado
# ==============================================================================
from sklearn import preprocessing
from sklearn import utils
from sklearn import set_config
from sklearn import svm
from sklearn.cluster import KMeans
from sklearn.compose import ColumnTransformer, make_column_selector
from sklearn.ensemble import RandomForestClassifier, VotingClassifier, RandomForestRegressor
from sklearn.impute import SimpleImputer
from sklearn.inspection import permutation_importance
from sklearn.preprocessing import StandardScaler, RobustScaler, OneHotEncoder, StandardScaler, LabelEncoder
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression, LinearRegression, Perceptron, Ridge
from sklearn.metrics import f1_score, accuracy_score, confusion_matrix, r2_score, mean_squared_error, classification_report, mean_absolute_error, roc_auc_score
from sklearn.mixture import GaussianMixture
from sklearn.model_selection import train_test_split, cross_val_score, cross_val_predict, cross_validate, KFold, RepeatedKFold,  GridSearchCV, RandomizedSearchCV
from sklearn.neighbors import KNeighborsRegressor
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.preprocessing import OneHotEncoder, PolynomialFeatures
from sklearn.tree import DecisionTreeRegressor


# estadisticos
# ==============================================================================
import statsmodels.api as sm

# Configuración warning
# ==============================================================================
import warnings
warnings.filterwarnings(action="ignore")
pd.set_option("float_format", '{:.1f}'.format)
# Configuración matplotlib
# ==============================================================================
plt.rcParams['image.cmap'] = "bwr"
#plt.rcParams['figure.dpi'] = "100"
plt.rcParams['savefig.bbox'] = "tight"
style.use('ggplot') or plt.style.use('ggplot')
import multiprocessing
import shap

# %% [markdown]
# # El Archivo y Su tamaño

# %%
# llamamos el proyecto ha utilizar

proyecto1 = pd.read_csv('DS_Proyecto_01_Datos_Properati.csv') 

# Dimensiones del dataset
# ==============================================================================
Tamaño_proyecto1= proyecto1.shape
print(proyecto1.shape)
# Out:
# (146660, 19)

# %% [markdown]
# # <div align="center">Filtrado, Número de observaciones y valores ausentes</div>
# <div align="center">
# <img src="https://image.freepik.com/foto-gratis/gente-negocios-discutiendo-resultados-trabajo-equipo-exitoso_1421-95.jpg" alt="drawing" style="width:1000px;height: 400px"/></div>
#
# Seguiremos con el tamaño sugerido en el primer módulo, ya que comprende a un buen dimensionamiento y puede ofrecer una buena estrategia para predecir.

# %%
# traemos el filtrado segun el analisis exploratorio del proyecto 1
# Filtrando el Dataframe
# Vamos a filtrar el dataset los datos categóricos en properti_type que tienen mayor cantidad de información


Filtrando_el_Dataset_proyecto2 = proyecto1
Filtrando_el_Dataset_proyecto2 = Filtrando_el_Dataset_proyecto2[proyecto1.property_type.isin(["Departamento", "Casa", "PH"])]


print("Filtrando del 98% de los datos (Departamento, Casa, PH) queda con un total de (instancias x Columnas) = ", )
print('                    ',Filtrando_el_Dataset_proyecto2.shape)
print('                    ')

# Vamos a filtrar el dataset con la mayoria con la Region con la mayor cantidad de datos

proyecto2 = Filtrando_el_Dataset_proyecto2
proyecto2 = proyecto2[Filtrando_el_Dataset_proyecto2.l2.isin(["Capital Federal"])]
Data_proyecto2 = proyecto2.shape

print("                       *******")
print('                    ')
print("Dejando solo la región de capital federal en el data Set queda de (instancias x Columnas) = ", )
print('                    ',proyecto2.shape)
# Out:
# Filtrando del 98% de los datos (Departamento, Casa, PH) queda con un total de (instancias x Columnas) =
#                      (143145, 19)
#
#                        *******
#
# Dejando solo la región de capital federal en el data Set queda de (instancias x Columnas) =
#                      (91485, 19)

# %% [markdown]
# # <div align="center">Análisis exploratorio</div>
#
# Antes de entrenar un modelo predictivo, o incluso antes de realizar cualquier cálculo con un nuevo conjunto de datos, es muy importante realizar una exploración descriptiva de los mismos. Este proceso permite entender mejor qué información contiene cada variable, así como detectar posibles errores. Algunos ejemplos frecuentes son:
#
#      * Que una columna se haya almacenado con el tipo incorrecto: una variable numérica está siendo reconocida como texto o viceversa.
#
#      * Que una variable contenga valores que no tienen sentido: por ejemplo, para indicar que no se dispone del precio de una vivienda se introduce el valor 0 o un espacio en blanco.
#
#     * Que en una variable de tipo numérico se haya introducido una palabra en lugar de un número.
#
# Además, este análisis inicial puede dar pistas sobre qué variables son adecuadas como predictores en un modelo (más sobre esto en los siguientes apartados).

# %%
proyecto2.sample(4)
# Out:
#         start_date    end_date  created_on   lat   lon         l1  \
# 7460    2019-04-27  2019-07-10  2019-04-27 -34.6 -58.5  Argentina
# 109160  2019-10-18  2019-11-04  2019-10-18 -34.6 -58.4  Argentina
# 128903  2019-06-29  2019-06-30  2019-06-29 -34.6 -58.4  Argentina
# 71854   2019-01-15  2019-06-23  2019-01-15 -34.6 -58.4  Argentina
#
#                      l2            l3  rooms  bedrooms  bathrooms  \
# 7460    Capital Federal  Monte Castro    2.0       1.0        2.0
# 109160  Capital Federal       Palermo    2.0       1.0        1.0
# 128903  Capital Federal        Abasto    3.0       2.0        1.0
# 71854   Capital Federal      Recoleta    5.0       4.0        2.0
#
#         surface_total  surface_covered    price currency  \
# 7460             57.0             48.0 139000.0      USD
# 109160           49.0             49.0 230000.0      USD
# 128903           81.0             75.0 175000.0      USD
# 71854           287.0            287.0 620000.0      USD
#
# ...

# %%
# vemos la información total de todo el dataset filtrado.
# Tipo de cada columna
# ==============================================================================
# En pandas, el tipo "object" hace referencia a strings
# datos.dtypes

proyecto2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 91485 entries, 0 to 146558
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   start_date       91485 non-null  object
#  1   end_date         91485 non-null  object
#  2   created_on       91485 non-null  object
#  3   lat              86951 non-null  float64
#  4   lon              86937 non-null  float64
#  5   l1               91485 non-null  object
#  6   l2               91485 non-null  object
#  7   l3               91485 non-null  object
#  8   rooms            91485 non-null  float64
#  9   bedrooms         91485 non-null  float64
#  10  bathrooms        89314 non-null  float64
#  11  surface_total    82568 non-null  float64
#  12  surface_covered  82250 non-null  float64
#  13  price            91485 non-null  float64
#  14  currency         91485 non-null  object
#  15  title            91485 non-null  object
# ...

# %% [markdown]
# # <div align="center">Tipo de Datos de cada columna</div>

# %%
# vemos las estadisticas del nuevo Dataset
proyecto2.describe()
# Out:
#           lat     lon   rooms  bedrooms  bathrooms  surface_total  \
# count 86951.0 86937.0 91485.0   91485.0    89314.0        82568.0
# mean    -34.6   -58.4     3.0       2.0        1.6          112.6
# std       0.0     0.0     1.3       1.1        0.9          980.7
# min     -34.7   -58.5     1.0       0.0        1.0           10.0
# 25%     -34.6   -58.5     2.0       1.0        1.0           49.0
# 50%     -34.6   -58.4     3.0       2.0        1.0           71.0
# 75%     -34.6   -58.4     4.0       3.0        2.0          111.0
# max     -34.5   -58.4    26.0      15.0       14.0       126062.0
#
#        surface_covered      price
# count          82250.0    91485.0
# mean              95.0   259500.3
# std              778.5   322265.4
# min                1.0     6000.0
# 25%               44.0   120000.0
# 50%               63.0   175000.0
# 75%               96.0   279000.0
# max           126062.0 32434232.0

# %% [markdown]
# ###  según la descripción de este cuadro podríamos decir que los siguiente variables numéricas son:
#         * Parece que las variables 'bathrooms', 'rooms', 'bedrooms' distribuyen normal
#         * lat y lon su desviación Estandar es 0, porque tal vez pertenecen todos a la capital, lo cual  no serviria de mucho.
#         * Las variables 'surface_total', 'surface_covered', el sesgo es muy alto.

# %% [markdown]
# ## Variables cualitativas

# %%
# Variables cualitativas (tipo object)
# ==============================================================================
proyecto2.describe(exclude='number')
# Out:
#         start_date    end_date  created_on         l1               l2  \
# count        91485       91485       91485      91485            91485
# unique         362         408         362          1                1
# top     2019-07-31  9999-12-31  2019-07-31  Argentina  Capital Federal
# freq          6951       10986        6951      91485            91485
#
#              l3 currency                  title  \
# count     91485    91485                  91485
# unique       57        1                  43106
# top     Palermo      USD  DEPARTAMENTO EN VENTA
# freq      13007    91485                   3377
#
#                                               description property_type  \
# count                                               91485         91485
# unique                                              58676             3
# top     EDIFICIO DE CATEGORIA CON MATERIALES Y ACCESOR...  Departamento
# freq                                                  235         79029
#
# ...

# %% [markdown]
# ###  Segun la descripción de este cuadro podriamos decir los siguiente de las variables categoricas:
#
#         * La fecha que tiene mas datos 6951 en total es 2019-07-31
#         * La fecha de extracción del data set quedaron 10986 instancias en total.
#         * El barrio con mas anuncios es Palermo
#         * l1, l2, currency, title, description, con este filtrado ya no nos dicen mucho.
#         * La mayor propiedad con anuncios es Departamento.
#         * Todos los anuncios son para ventas.

# %% [markdown]
# ## <div align="center">Datos</div>
#
#
# #### El set de datos Properati contiene información sobre el precio de 143.145 propiedades situadas en Argentina, la mayor parte de los datos son Departamento, Casa, PH con 143.145 instancias y las que vamos a analizar están Ciudad capital que contiene 91.485 estancias. Además del precio, incluye 18 variables adicionales:
#
#      1   start_date       Fecha_de_inicio            = Fecha de que se publica el anuncio
#      2   end_date         Fecha_del_fin_del_anuncio  = Fecha fin del anuncio
#      3   created_on       Fecha_de_Creción           = Fecha de creación anuncio
#      4   lat              Latitud                   = geolocalización de la propiedad
#      5   lon              Longitud                    = geolocalización de la propiedad
#      6   l1               País                       = País del anuncio
#      7   l2               Ciudad                     = Ciudad del anuncio
#      8   l3               Barrio                     = Barrio de donde es el anuncio
#      9   rooms            Cuartos                    = número de salones.
#      10  bedrooms         Habitaciones               = Número de habitaciones
#      11  bathrooms        Baños                      = Numero de Baños
#      12  surface_total    Superficie_total           = La Superficie total de la propiedad en Metros cuadrados  Mts2.
#      13  surface_covered  Superficie_cubierta       = La Superficie construida de la propiedad en Metros cuadrados  Mts2.
#      14  price            Precio_USD                 = Precio de la propiedad en dólares estadounidenses
#      15  currency         Moneda                     = Tipo de moneda
#      16  title            Titulo                     = Titulo del anuncio
#      17  description      Descripción                = Descripción  del anuncio
#      18  property_type    Tipo_de_propiedad          = el tipo de vivienda
#      19  operation_type   Tipo_de_operación          = Todas son para la venta.
#
#  #### El objetivo es optimizar y mejorar el modelo del proyecto 1, para que sea capaz de predecir el precio del venta de una propiedad (Departamento, Casa, PH) en la capital de Buenos Aires.

# %%
# Vamos a separar las variables categoricas y cambiarle el nombre a dichas columnas
#=========================================================================================================

Categoricas = proyecto2.select_dtypes(exclude='number').columns.tolist()
Categoricas = pd.DataFrame(
    { 
    'Barrio'	                  : proyecto2['l3'],
    'Tipo_de_propiedad'           : proyecto2['property_type']
    },  
  
    columns=['Barrio','Tipo_de_propiedad'],
)

#'Fecha_de_inicio'           : proyecto2['start_date'], * descartemos esta columna
#'Fecha_del_fin_del_anuncio' : proyecto2['end_date'], * descartemos esta columna
#'Fecha_de_Creción'          : proyecto2['created_on'], * descartemos esta columna
# 'Fecha_de_inicio','Fecha_del_fin_del_anuncio','Fecha_de_Creción',
# Separemos las variables numericas y cambiemos el nombre a dichas columnas,

numericas = proyecto2.select_dtypes(include='number').columns.tolist()
numericas = pd.DataFrame(
    {
        'Precio_USD'         : proyecto2['price'],
        'Latitud'            : proyecto2['lat'], 
        'Longitud'           : proyecto2['lon'],
        'Cuartos'            : proyecto2['rooms'],
        'Habitaciones'       : proyecto2['bedrooms'],
        'Baños'              : proyecto2['bathrooms'],
        'Superficie_total'   : proyecto2['surface_total'], 
        'Superficie_cubierta': proyecto2['surface_covered']
    },  
  
    columns=['Longitud','Latitud','Cuartos','Habitaciones','Superficie_total','Baños','Superficie_cubierta','Precio_USD'],
)

# %%
# tamaño de todos las nuestros numericas en un Histogramas
#======================================================================================

fig = plt.figure(figsize = (15,20))
ax = fig.gca()

# Se realiza todos los histogramas de estas columnas numericas, y se hace un escalado logaritmico a la imagen de los datos, para que
# la informacion no sea gris.
numericas.hist(color = 'g', bins=20, log= True, ax = ax, density=True, alpha=0.75);
plt.show();

# %% [markdown]
# #### Utilizando la forma algorítmica en el histograma, los datos nos muestran una mejor distribución también los datos atípicos o outliers.
#            * Cuartos puede verse distribuido en escala descendente entre 1 - 19 salones, después pareciera tener datos atípicos.
#            * Las Habitaciones tienen mayor cantidad de datos entre 2 - 4 a partir de 10 ya empieza a parecer que tiene muchos datos atípicos.
#            * Superficie Total y superficie cubierta tienden a parecerse.
#            * Baños la mayor cantidad de las instancias tiene 1 y 2.
#            * la mayoría de las propiedades cuestan menos USD 600.000

# %%
# realizamos un subplot de cada variable numericas
#======================================================================================

fig = plt.figure(figsize = (20,20))
fig.suptitle('Boxplots Variables numericas antes de limpiar los outliers en el dataset ', fontsize=15)

plt.subplot(4,2,1)
sns.boxplot(data = numericas, y = 'Cuartos', color='y')
plt.ylabel('Cantidad de cuartos', size = 10)
plt.ylim()
plt.title('Cuartos', fontsize=10, color='y' )

plt.subplot(4,2,2)
sns.boxplot(data = numericas, y = 'Habitaciones', color='indigo')
plt.ylabel('Cantidad de Habitaciones', size = 10)
plt.ylim()
plt.title('Habitaciones', fontsize=10, color='indigo')


plt.subplot(4,2,3)
sns.boxplot(data = numericas, y = 'Superficie_total', color='g')
plt.ylabel('Cantidad de metros cuadrados', size = 10)
plt.ylim()
plt.title('Superficie total', fontsize=10, color='g')


plt.subplot(4,2,4)
sns.boxplot(data = numericas, y = 'Superficie_cubierta', color='pink')
plt.ylabel('Cantidad de metros cuadrados', size = 10)
plt.ylim()
plt.title('Superficie cubierta', fontsize=8, color='r')
   
plt.subplot(4,2,5)
sns.boxplot(data = numericas, y = 'Baños', color='darkgoldenrod')
plt.ylabel('Cantidad de Baños', size = 10)
plt.ylim()
plt.title('Baños', fontsize=10, color='darkgoldenrod')

plt.subplot(4,2,6)
sns.boxplot(data = numericas, y = 'Precio_USD', color='c')
plt.ylabel('Precio en USD', size = 10)
plt.ylim()
plt.title('Precio USD', fontsize=10, color='c')

plt.subplot(4,2,7)
sns.boxplot(data = numericas, y = 'Latitud', color='greenyellow')
plt.ylabel('Latitud de los anuncios', size = 10)
plt.ylim()
plt.title('Latitud', fontsize=10, color='greenyellow' )

plt.subplot(4,2,8)
sns.boxplot(data = numericas, y = 'Longitud', color='aqua')
plt.ylabel('longitud de los anuncios', size = 10)
plt.ylim()
plt.title('Longitud', fontsize=10, color='aqua')

  
plt.show()

# %% [markdown]
# ### los Boxplot Nos demuestran nuestra teoría que sin limpiar la información de e Dataset, las imágenes no nos dirían mucho, vemos muchos datos atípicos, aunque podemos decir que cantidad Cuartos y Habitaciones tiene una distribución muy parecida

# %% [markdown]
# # <div align="center">PARTE A - Transformación de Datos</div>
# <div align="center">
# <img src="https://as2.ftcdn.net/jpg/04/33/20/57/500_F_433205784_dUVWALOIXruVdrwTFzhrf7UvkAQGY3M1.jpg" alt="drawing" style="width:700px;height: 400px"/></div>
#
# Detección y eliminación de Outlets
#
# Utilizaremos las estadísticas para transformación de nuestro Dataset -- detección y eliminación de Outlets.
# Quiero replantear la formula para no castigar tanto los datos atípicos por tal motivo voy a multiplicar la IQR (Rangos Inter cuartiles Q3 - Q1 ) x 2.

# %%
# Transformación de Datos -- detección y eliminación de Outlets
#======================================================================================

Q1 = numericas.quantile(0.25)
Q3 = numericas.quantile(0.75)
IQR = Q3- Q1
MIN = Q1 - 2*IQR
MAX = Q3 + 2*IQR

 

print('Estos serían los rangos Inter cuartiles IQR (= Min(0.25% de los datos)- Max(0.75 % de los datos))')
print('o la dispersión de la distribución de los datos, los cuales Son:')
print(             )
print(IQR)
print(             )
print('----------********-------')
print(             )
print('Los rangos mínimos son: ')
print(             )
print(MIN)
print(             )
print('----------********-------')
print(             )
print('Los rangos máximos son: ')
print(             )
print(MAX)
# Out:
# Estos serían los rangos Inter cuartiles IQR (= Min(0.25% de los datos)- Max(0.75 % de los datos))
# o la dispersión de la distribución de los datos, los cuales Son:
#
# Longitud                   0.0
# Latitud                    0.0
# Cuartos                    2.0
# Habitaciones               2.0
# Superficie_total          62.0
# Baños                      1.0
# Superficie_cubierta       52.0
# Precio_USD            159000.0
# dtype: float64
#
# ----------********-------
#
# Los rangos mínimos son:
#
# Longitud                  -58.6
# Latitud                   -34.7
# Cuartos                    -2.0
# Habitaciones               -3.0
# Superficie_total          -75.0
# Baños                      -1.0
# Superficie_cubierta       -60.0
# Precio_USD            -198000.0
# dtype: float64
#
# ----------********-------
#
# Los rangos máximos son:
#
# Longitud                 -58.3
# Latitud                  -34.5
# Cuartos                    8.0
# Habitaciones               7.0
# ...

# %%
# realizamos un remodelado del data set uniendo la partición en categoricos y numericos anterior.
#=================================================================================================

New_proyecto2 = pd.concat([Categoricas, numericas], axis=1) 

# Realizamos una partición por el tipo de propiedad
data_Departamento = New_proyecto2["Tipo_de_propiedad"].isin(['Departamento'])
data_PH = New_proyecto2["Tipo_de_propiedad"].isin(['PH'])
data_Casa = New_proyecto2["Tipo_de_propiedad"].isin(['Casa'])

# dimensión de los datos
print ('Queda con un total de (instancias x Columnas) = ',New_proyecto2.shape)
# Out:
# Queda con un total de (instancias x Columnas) =  (91485, 10)

# %%
# con las medidas estadisticas anteriores realizamos un filtrado sin datos atipicos asi:
#======================================================================================

outliers = New_proyecto2[(proyecto2.rooms<8)  & (proyecto2.rooms>0) &
                                  (proyecto2.bedrooms<7)  & (proyecto2.bedrooms>0) &
                                  (proyecto2.bathrooms<4)  & (proyecto2.bathrooms>0) &
                                  (proyecto2.surface_total<235)  & (proyecto2.surface_total>0) &
                                  (proyecto2.surface_covered<200)  & (proyecto2.surface_total>0) &
                                  (proyecto2.price<597000)  & (proyecto2.price>0)] 
total_data= outliers.shape


outliers_numericas= outliers.select_dtypes(include='number').columns.tolist() 
outliers_categoricas = outliers.select_dtypes(exclude='number').columns.tolist() 

# nuestro data set se reduce a:

Tamaño_proyecto1

# outliers[outliers_numericas].head()

print ('Queda con un total de (instancias x Columnas) = ', outliers.shape, 'equivale ', 
      int((total_data[0]/Tamaño_proyecto1[0])*100),'% de los instancias totales del DataSet de Properati,')
print(' y al', int((total_data[0]/Data_proyecto2[0])*100),'% de los instancias totales de Capital Federal.')
# Out:
# Queda con un total de (instancias x Columnas) =  (71818, 10) equivale  48 % de los instancias totales del DataSet de Properati,
#  y al 78 % de los instancias totales de Capital Federal.

# %%
# tambien realizamos un filtrado con la variable categorica Tipo_de_propiedad, para ver la cantidad de datos que equivalen en nuestro Dataset
#============================================================================================================================================

outliers_Num_Departamentos = outliers["Tipo_de_propiedad"].isin(['Departamento'])
outliers_Num_PH = outliers["Tipo_de_propiedad"].isin(['PH'])
outliers_Num_Casas = outliers["Tipo_de_propiedad"].isin(['Casa'])

total_data_Departamento = outliers[outliers_Num_Departamentos].shape
total_data_PH = outliers[outliers_Num_PH].shape
total_data_Casa = outliers[outliers_Num_Casas].shape

print('Departamento tiene en total (instancias x Columnas) = ', outliers[outliers_Num_Departamentos].shape, ',equivale ', 
      int((total_data_Departamento[0]/total_data[0])*100),'% de los datos')

print('------------------------------<!>--------------------------------------')
print('PH tiene en total  (instancias x Columnas) = ', outliers[outliers_Num_PH].shape, ',equivale ', 
      int((total_data_PH[0]/total_data[0])*100),'% de los datos')
print('------------------------------<!>--------------------------------------')

print('Casa tiene en total  (instancias x Columnas) = ',outliers[outliers_Num_Casas].shape, ',equivale ', 
      int((total_data_Casa[0]/total_data[0])*100),'% de los datos')
# Out:
# Departamento tiene en total (instancias x Columnas) =  (62531, 10) ,equivale  87 % de los datos
# ------------------------------<!>--------------------------------------
# PH tiene en total  (instancias x Columnas) =  (8331, 10) ,equivale  11 % de los datos
# ------------------------------<!>--------------------------------------
# Casa tiene en total  (instancias x Columnas) =  (956, 10) ,equivale  1 % de los datos

# %%
# Graficamos el nuevo dataset
#======================================================================================


fig = plt.figure(figsize = (20,20))
fig.suptitle('Boxplots Variables numericas despues de limpiar los outliers en el dataset ', fontsize=15)


plt.subplot(4,2,1)
sns.boxplot(data = outliers, y = 'Cuartos', color='y')
plt.ylabel('Cantidad de cuartos', size = 10)
plt.ylim()
plt.title('Cuartos', fontsize=10, color='y' )

plt.subplot(4,2,2)
sns.boxplot(data = outliers, y = 'Habitaciones', color='indigo')
plt.ylabel('Cantidad de Habitaciones', size = 10)
plt.ylim()
plt.title('Habitaciones', fontsize=10, color='indigo')


plt.subplot(4,2,3)
sns.boxplot(data = outliers, y = 'Superficie_total', color='g')
plt.ylabel('Cantidad de metros cuadrados', size = 10)
plt.ylim()
plt.title('Superficie total', fontsize=10, color='g')


plt.subplot(4,2,4)
sns.boxplot(data = outliers, y = 'Superficie_cubierta', color='pink')
plt.ylabel('Cantidad de metros cuadrados', size = 10)
plt.ylim()
plt.title('Superficie cubierta', fontsize=8, color='r')
   
plt.subplot(4,2,5)
sns.boxplot(data = outliers, y = 'Baños', color='darkgoldenrod')
plt.ylabel('Cantidad de Baños', size = 10)
plt.ylim()
plt.title('Baños', fontsize=10, color='darkgoldenrod')

plt.subplot(4,2,6)
sns.boxplot(data = outliers, y = 'Precio_USD', color='c')
plt.ylabel('Precio en USD', size = 10)
plt.ylim()
plt.title('Precio USD', fontsize=10, color='c')

plt.subplot(4,2,7)
sns.boxplot(data = outliers, y = 'Latitud', color='greenyellow')
plt.ylabel('Latitud de los anuncios', size = 10)
plt.ylim()
plt.title('Latitud', fontsize=10, color='greenyellow' )

plt.subplot(4,2,8)
sns.boxplot(data = outliers, y = 'Longitud', color='aqua')
plt.ylabel('longitud de los anuncios', size = 10)
plt.ylim()
plt.title('Longitud', fontsize=10, color='aqua')

 
plt.show()

# %% [markdown]
# #### transformando los datos sin tantos datos atípicos encontramos, una mejor proporción de los datos, también podemos decir:
#     * Superficie total y superficie cubierta tienen unos gráficos muy parecida, con dispersión normal.
#     * Baños, Habitaciones y cuartos con una media muy dispersa en estos datos.
#     * El precio tiene una dispersión normal.
#     * Longitud y Latitud son datos que podrian servir mucho en nuestro modelo , ya que tienen una dispersion muy buena.

# %%
# la distribución de la variable respuesta, ya que, a fin de cuentas, es lo que interesa predecir Price. 

#======================================================================================

fig, axes = plt.subplots(nrows=3, ncols=1, figsize=(6, 6))
sns.distplot(
    outliers[outliers_numericas],
    hist    = False,
    rug     = True,
    color   = "blue",
    kde_kws = {'shade': True, 'linewidth': 1},
    ax      = axes[0]
)
axes[0].set_title("Distribución original", fontsize = 'medium')
axes[0].set_xlabel('Precio_USD', fontsize='small') 
axes[0].tick_params(labelsize = 6)

sns.distplot(
    np.sqrt(outliers[outliers_numericas]),
    hist    = False,
    rug     = True,
    color   = "blue",
    kde_kws = {'shade': True, 'linewidth': 1},
    ax      = axes[1]
)
axes[1].set_title("Transformación raíz cuadrada", fontsize = 'medium')
axes[1].set_xlabel('sqrt(precio)', fontsize='small') 
axes[1].tick_params(labelsize = 6)

sns.distplot(
    np.log(outliers[outliers_numericas]),
    hist    = False,
    rug     = True,
    color   = "blue",
    kde_kws = {'shade': True, 'linewidth': 1},
    ax      = axes[2]
)
axes[2].set_title("Transformación logarítmica", fontsize = 'medium')
axes[2].set_xlabel('log(precio)', fontsize='small') 
axes[2].tick_params(labelsize = 6)

fig.tight_layout()

# %% [markdown]
# Con la dispersión de la variable que queremos predecir, observamos que aunque la mayoría de datos distribuyen normal en dos categorías y hay algunos datos dispersos en USD 400.000.

# %%
# sns.pairplot(outliers, hue="Tipo_de_propiedad",markers=["o", "s", "D"],  palette=["b", "g", "y"], diag_kind="kde", corner=True)
#======================================================================================

call = outliers[outliers_numericas].drop(["Precio_USD"], axis=1)

fig,  figsize=(9, 5)
for column in call:
    print(f"Para la variable {column}: \n")
    sns.lmplot(data=outliers, x=column, y="Precio_USD", hue="Tipo_de_propiedad")
    plt.show()
# Out:
# Para la variable Longitud:
# Para la variable Latitud:
# Para la variable Cuartos:
# Para la variable Habitaciones:
# Para la variable Superficie_total:
# Para la variable Baños:
# Para la variable Superficie_cubierta:

# %% [markdown]
# #### Observamos que las variables que mejor distribuyen son Superficie_cubierta y Superficie_total. Las variables categóricas PH y Departamento tienes una ecuación de las rectas muy parecidas.

# %% [markdown]
# # Mapas de Calor y correlacciones

# %%
# Graficamos la correlación para ver el comportamiento de todos los datos
#======================================================================================

corr = outliers[outliers_numericas].corr(method='pearson') # .corr is used for find corelation
plt.figure(figsize=(7,7))
sns.heatmap(corr, cbar = True,  square = True, annot=True, fmt= '.2f',annot_kws={'size': 10},
           xticklabels= corr.columns, 
           yticklabels= corr.columns,
           cmap= 'coolwarm')
plt.title('correlación de todas las variables numericas')

plt.show()

# %%
# Graficamos la correlación de departamento para ver el comportamiento de todos los datos
#======================================================================================


corr_Departamento = outliers[outliers_Num_Departamentos].corr(method='pearson') # .corr is used for find corelation
plt.figure(figsize=(7,7))
sns.heatmap(corr_Departamento, cbar = True,  square = True, annot=True, fmt= '.2f',annot_kws={'size': 10},
           xticklabels= corr_Departamento.columns, 
           yticklabels= corr_Departamento.columns,
           cmap= 'coolwarm')
plt.title('correlación de las variables numericas En Departamento')

plt.show()

# %%
# Graficamos la correlación de PH para ver el comportamiento de todos los datos
#======================================================================================

corr_PH = outliers[outliers_Num_PH].corr(method='pearson') # .corr is used for find corelation
plt.figure(figsize=(7,7))
sns.heatmap(corr_PH, cbar = True,  square = True, annot=True, fmt= '.2f',annot_kws={'size': 10},
           xticklabels= corr_PH.columns, 
           yticklabels= corr_PH.columns,
           cmap= 'coolwarm')
plt.title('correlación de todas las variables En PH')

plt.show()

# %%
# Graficamos la correlación de Casa para ver el comportamiento de todos los datos
#======================================================================================

corr_Casa = outliers[outliers_Num_Casas].corr(method='pearson') # .corr is used for find corelation
plt.figure(figsize=(7,7))
sns.heatmap(corr_Casa, cbar = True,  square = True, annot=True, fmt= '.2f',annot_kws={'size': 10},
           xticklabels= corr_PH.columns, 
           yticklabels= corr_PH.columns,
           cmap= 'coolwarm')
plt.title('Correlación de todas las variables En Casas')

plt.show()

# %% [markdown]
# ###  Según la descripción de este Mapas de calor podríamos decir los siguiente sobre correlaciones de las variables numéricas:
#
#         * PH y Departamento tienden a parecerse mucho a el total de los datos de tipo de propiedad
#         * Casa al parecer no tiene datos numéricos correlacionados con el precio

# %% [markdown]
# # <div align="center">Número de observaciones y valores ausentes</div>
# <div align="center">
# <img src="https://image.freepik.com/foto-gratis/hombre-joven-hermoso-que-mira-escritura-ausente-papel-lapiz-ordenador-portatil-tabla_23-2148096464.jpg" alt="drawing" style="width:1000px;height: 500px"/></div>
#
# Junto con el estudio del tipo de variables, es básico conocer el número de observaciones disponibles y si todas ellas están completas. Los valores ausentes son muy importantes a la hora de crear modelos se ven muy influenciados con los datos ausentes

# %%
# Graficamente podemos ver donde donde estan los datos faltantes dentro del dataset, para poder tener idea 
# de la extructura de los datos. Número de datos ausentes por variable
# ==============================================================================
fig, ax = plt.subplots(figsize=(15,6))

dat= outliers[outliers_numericas].isnull()
heat = sns.heatmap(dat.T, cmap="coolwarm", xticklabels=False)
plt.title('Datos Faltantes (=1) dentro del Dataset')
plt.xlabel('Instancias dentro del Dataset')
plt.ylabel('elemento columna del Dataset')
plt.tight_layout()
print(outliers[outliers_numericas].isna().sum())
# Out:
# Longitud               3317
# Latitud                3317
# Cuartos                   0
# Habitaciones              0
# Superficie_total          0
# Baños                     0
# Superficie_cubierta       0
# Precio_USD                0
# dtype: int64

# %%
print('Datos faltantes en departamentos')
print(outliers[outliers_Num_Departamentos].isna().mean())
print('-----------------------<*!*>-------------------')
print('Datos faltantes en PH')
print(outliers[outliers_Num_PH].isna().mean())
print('-----------------------<*!*>-------------------')
print('Datos faltantes en Casa')
print(outliers[outliers_Num_Casas].isna().mean())
print('-----------------------<*!*>-------------------')
# Out:
# Datos faltantes en departamentos
# Barrio                0.0
# Tipo_de_propiedad     0.0
# Longitud              0.1
# Latitud               0.1
# Cuartos               0.0
# Habitaciones          0.0
# Superficie_total      0.0
# Baños                 0.0
# Superficie_cubierta   0.0
# Precio_USD            0.0
# dtype: float64
# -----------------------<*!*>-------------------
# Datos faltantes en PH
# Barrio                0.0
# Tipo_de_propiedad     0.0
# Longitud              0.0
# Latitud               0.0
# Cuartos               0.0
# Habitaciones          0.0
# Superficie_total      0.0
# Baños                 0.0
# Superficie_cubierta   0.0
# Precio_USD            0.0
# dtype: float64
# -----------------------<*!*>-------------------
# Datos faltantes en Casa
# Barrio                0.0
# Tipo_de_propiedad     0.0
# Longitud              0.0
# Latitud               0.0
# Cuartos               0.0
# Habitaciones          0.0
# Superficie_total      0.0
# ...

# %% [markdown]
# #### Se observa que la transformación elegida de detección y eliminación de Outliers, fue  apropiada, pero hay datos faltantes y están en su gran mayoría en las variables de longitud y latitud, corresponde a 3317 instancias, las cuales vamos utilizar la transformación de Datos missing

# %%
# Valores observados en tipo de propiedad
# ==============================================================================

fig, ax = plt.subplots(figsize=(12,8))

sns.boxplot(x="Tipo_de_propiedad", y="Precio_USD", hue="Tipo_de_propiedad", palette=["b", "g", "y"], data=outliers)
plt.ylabel('Precio en Dolares Estado Unidenses', fontsize=15)
plt.xlabel('Tipo de Propiedad', size = 15)
plt.title('Diagrama de caja precio en USD VS el tipo de propiedad', fontsize=25)
plt.show()

# %% [markdown]
# Con este diagrama de Bigotes podemos observar cómo distribuye nuestra variable objetivo con nuestra variable categoría, vemos que PH y Departamento siguen mostrando una similitud en precios y distribución, la categoría casa muestra que su valor es más alto.

# %%
## podriamos saber el valor promedio por barrio en Buenos Aires

# convertimos un Dataframe la suma de la agrupacion de datos 
#======================================================================================

outliers1 = pd.DataFrame(outliers.groupby('Barrio').agg(np.mean))

# ordenamos el Datafrem por una columna
outliers2 = outliers1.sort_values('Precio_USD', ascending=False)
# Grafico resultante del valor de la propiedad segun el barrio

fig, ax = plt.subplots(figsize=(20,8))


ax=sns.barplot(data = outliers2.reset_index(), x = 'Barrio', y = "Precio_USD", ci = 0, palette='coolwarm')

plt.xticks(rotation = 70)
plt.xlabel('Barrios de Buenos aires', fontsize=20)
plt.ylabel('Precio en promedio de las propiedades en Buenos aires', fontsize=20)
plt.title('Precio en promedio propiedad en USD VS Barrio', fontsize=25)
plt.show()

# %% [markdown]
# Con la otra variable categórica "Barrio" Vs nuestra variable objetiva,  podemos ver que el precio promedio en los barrios de Buenos Aires, es que la mayoría de los barrios tiene un precio de sus  propiedades muy cercano a los USD 150.000, también que en los barrios Villa Soldati y constitución puede tener la mayoría de sus propiedades por debajo de USD 100.000 y que el Barrio con propiedades en promedio cercano a los USD 400.000 es Puerto madero.

# %% [markdown]
# ## Datos missing
#
# Evaluaremos nuevamente la capacidad predictiva de nuestro modelo del Sprint  1 vamos a comprobar cómo seran sus predicciones a los verdaderos valores de la variable respuesta.
# Pero antes vamos a evaluar Los datos faltantes ya que son un problema,   y puede generar errores en el resultado

# %%
outliers.isna().sum()
# Out:
# Barrio                    0
# Tipo_de_propiedad         0
# Longitud               3317
# Latitud                3317
# Cuartos                   0
# Habitaciones              0
# Superficie_total          0
# Baños                     0
# Superficie_cubierta       0
# Precio_USD                0
# dtype: int64

# %%
msno.matrix(df=outliers)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Hay datos Missing  longitud 3317 y 3317 en latitud lo que equivalen 4,62% de los datos.

# %%
# dividíamos nuestros datos en numéricos y categóricos
# ==============================================================================

numeric_cols = ['Latitud','Longitud','Cuartos','Habitaciones', 'Superficie_total','Baños', 'Superficie_cubierta']

cat_cols = ['Tipo_de_propiedad', 'Barrio']


outliers1 = outliers[numeric_cols + cat_cols + ['Precio_USD']]
outliers1.head()
# Out:
#    Latitud  Longitud  Cuartos  Habitaciones  Superficie_total  Baños  \
# 1    -34.6     -58.4      2.0           1.0              70.0    2.0
# 2    -34.6     -58.4      2.0           1.0              45.0    1.0
# 3    -34.6     -58.4      2.0           1.0              85.0    1.0
# 5    -34.6     -58.4      2.0           1.0              56.0    1.0
# 6    -34.6     -58.4      2.0           1.0              70.0    1.0
#
#    Superficie_cubierta Tipo_de_propiedad        Barrio  Precio_USD
# 1                 58.0                PH         Boedo    159000.0
# 2                 45.0                PH       Palermo    125000.0
# 3                 50.0                PH       Palermo    295000.0
# 5                 56.0                PH  Villa Crespo    150000.0
# 6                 70.0                PH  Villa Crespo    159500.0

# %%
# Sacamos nuestra variable objetivo
# ==============================================================================
objetivo = outliers1['Precio_USD']

# %%
# Elimininamos elemento 'Precio_USD'de la lista.
# ==============================================================================
Precio = outliers1.pop('Precio_USD')

outliers1.head(10)
# Out:
#     Latitud  Longitud  Cuartos  Habitaciones  Superficie_total  Baños  \
# 1     -34.6     -58.4      2.0           1.0              70.0    2.0
# 2     -34.6     -58.4      2.0           1.0              45.0    1.0
# 3     -34.6     -58.4      2.0           1.0              85.0    1.0
# 5     -34.6     -58.4      2.0           1.0              56.0    1.0
# 6     -34.6     -58.4      2.0           1.0              70.0    1.0
# 7     -34.6     -58.4      2.0           1.0              70.0    1.0
# 8     -34.6     -58.4      1.0           1.0              45.0    1.0
# 9     -34.6     -58.4      1.0           1.0              45.0    1.0
# 10    -34.6     -58.5      2.0           1.0              66.0    2.0
# 11    -34.6     -58.4      2.0           1.0              68.0    1.0
#
#     Superficie_cubierta Tipo_de_propiedad            Barrio
# 1                  58.0                PH             Boedo
# 2                  45.0                PH           Palermo
# ...

# %%
# observamos la cantidad de elementos diferentes tiene nuestra variable objetivo
# ==============================================================================
objetivo.value_counts(normalize=True)
# Out:
# 125000.0   0.0
# 120000.0   0.0
# 115000.0   0.0
# 145000.0   0.0
# 110000.0   0.0
#             ..
# 169750.0   0.0
# 591361.0   0.0
# 213400.0   0.0
# 90343.0    0.0
# 114692.0   0.0
# Name: Precio_USD, Length: 3039, dtype: float64

# %% [markdown]
# #### hay 3039 diferentes precios

# %%
# Observamos la forma y tamaño de las matrices resultantes
# ==============================================================================

objetivo.shape, outliers.shape
# Out:
# ((71818,), (71818, 10))

# %% [markdown]
# ## Partimos en train y test

# %%
X_train, X_test, y_train, y_test  = train_test_split(outliers1, objetivo,
                                                    test_size=0.3,  random_state=42)

# %% [markdown]
# ## Pre-procesamiento (Escalado de datos, Imputación de valores faltantes)

# %%
# Utilizaremos SimpleImputer para sustituir valores nulos por otros valores según varias estrategias disponibles, para este caso  o
# Utilizaremos la media com Estrategia 
# ==============================================================================

imputer = SimpleImputer(strategy='median')

imputer.fit(X_test[numeric_cols])

imputer.statistics_
# Out:
# array([-34.599252  , -58.43359116,   3.        ,   2.        ,
#         66.        ,   1.        ,  59.        ])

# %% [markdown]
# #### Una vez instanciado el imputador, puede entrenarse con el método fit (que genera un array conteniendo los valores por los que sustituir los valores nulos de cada característica) y puede ejecutarse la sustitución con el método transform.

# %%
X_train[numeric_cols] = imputer.transform(X_train[numeric_cols])
X_test[numeric_cols] = imputer.transform(X_test[numeric_cols])

# %%
# StandardScaler realiza la tarea de Estandarización. Por si el conjunto de datos contiene variables que son diferentes en escala.
# ==============================================================================

scaler_train = StandardScaler().fit(X_train[numeric_cols])
scaler_test = StandardScaler().fit(X_test[numeric_cols])

print("La media en train es: ")
print(scaler_train.mean_)
print('__________/^\____________')
print("La media en test es:  ")
print(scaler_test.mean_)
print('__________/^\____________')
print("La sd en train es:  ")
print(scaler_train.scale_)
print('__________/^\____________')
print("La sd en test es:  ")
print(scaler_test.scale_)
print('__________/^\____________')
# Out:
# La media en train es:
# [-34.5986304  -58.43610034   2.78268221   1.83109882  75.92972231
#    1.37404519  66.67486871]
# __________/^\____________
# La media en test es:
# [-34.59877419 -58.43598164   2.79430057   1.84159473  76.00097466
#    1.37255175  66.74403602]
# __________/^\____________
# La sd en train es:
# [2.25433076e-02 3.42045131e-02 1.03072626e+00 8.56101729e-01
#  3.83956366e+01 5.85579787e-01 3.16015348e+01]
# __________/^\____________
# La sd en test es:
# [2.25366529e-02 3.38200569e-02 1.03031963e+00 8.59053456e-01
#  3.83301689e+01 5.88754383e-01 3.16537101e+01]
# __________/^\____________

# %%
# Transformo las columnas numericas
# ====================================================================

X_train[numeric_cols] = scaler_train.transform(X_train[numeric_cols])
X_test[numeric_cols] = scaler_test.transform(X_test[numeric_cols])

# %% [markdown]
# ## OneHotEncoder () vs pandas.get_dummies()
#
# Aunque OHE tiene muchas mas ventajas, pero para este set de datos voy utilizar Para una limpieza rápida de datos get_dummies, ya que tiene mucho mas entido usar pandas get dummies.

# %%
# Tratamiento de las columnas categoricas copn get_dummies de pandas
#===============================================================================

X_train_get= pd.get_dummies(data=X_train, columns=cat_cols)
X_test_get =  pd.get_dummies(data=X_test, columns=cat_cols)

# %%
# ejemplo de nuestro dataset de entrenamiento en dummies
#==================================================================================

X_train_get.sample(3)
# Out:
#        Latitud  Longitud  Cuartos  Habitaciones  Superficie_total  Baños  \
# 5894       0.8      -1.0     -0.8          -1.0              -0.8   -0.6
# 45382     -0.3       0.4      0.2           0.2              -0.2   -0.6
# 2389      -0.8       0.4      0.2           0.2               3.5   -0.6
#
#        Superficie_cubierta  Tipo_de_propiedad_Casa  \
# 5894                  -0.7                       0
# 45382                 -0.1                       0
# 2389                   3.1                       0
#
#        Tipo_de_propiedad_Departamento  Tipo_de_propiedad_PH  Barrio_Abasto  \
# 5894                                0                     1              0
# 45382                               1                     0              0
# 2389                                0                     1              0
#
#        Barrio_Agronomía  Barrio_Almagro  Barrio_Balvanera  Barrio_Barracas  \
# 5894                  0               0                 0                0
# ...

# %%
# ejemplo de nuestro dataset de test en dummies
#==================================================================================

X_test_get.sample(3)
# Out:
#        Latitud  Longitud  Cuartos  Habitaciones  Superficie_total  Baños  \
# 24458     -1.8       2.0     -0.8          -1.0              -0.4   -0.6
# 36674      1.4       0.0      0.2           0.2              -0.2   -0.6
# 49514      0.1      -0.2      0.2           0.2              -0.2   -0.6
#
#        Superficie_cubierta  Tipo_de_propiedad_Casa  \
# 24458                 -0.2                       0
# 36674                 -0.3                       0
# 49514                 -0.2                       0
#
#        Tipo_de_propiedad_Departamento  Tipo_de_propiedad_PH  Barrio_Abasto  \
# 24458                               1                     0              0
# 36674                               1                     0              0
# 49514                               1                     0              0
#
#        Barrio_Agronomía  Barrio_Almagro  Barrio_Balvanera  Barrio_Barracas  \
# 24458                 0               0                 0                1
# ...

# %%
# Todas las variables fueron imputadas correctamente 
#===============================================================

msno.bar(X_train)
# Out:
# <AxesSubplot:>

# %%
# Todas las variables fueron imputadas correctamente 
#===============================================================
msno.bar(X_test)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Las transformaciones de Los Datos se les realizaron de forma conveniente en:
#         * Detección y eliminación de Outliers,
#         * Encoding,
#         * Escalado de datos,
#         * Imputación de valores faltantes) escalados y nuevamente

# %%
# Observamos la forma de las matrices
# ==============================================================================

X_train_get.shape, y_train.shape
# Out:
# ((50272, 67), (50272,))

# %%
X_train.head()
# Out:
#         Latitud  Longitud  Cuartos  Habitaciones  Superficie_total  Baños  \
# 96441       0.9      -0.8      0.2           0.2               0.6    1.1
# 47292       0.0      -0.4     -0.8          -1.0              -0.3   -0.6
# 1246        0.9      -0.6     -0.8          -1.0              -0.5   -0.6
# 24647      -0.9      -0.2     -0.8          -1.0              -0.6   -0.6
# 113699     -0.4       0.8      0.2           0.2              -0.4   -0.6
#
#         Superficie_cubierta Tipo_de_propiedad         Barrio
# 96441                   0.7      Departamento  Villa Urquiza
# 47292                  -0.3      Departamento   Villa Crespo
# 1246                   -0.5      Departamento     Colegiales
# 24647                  -0.4      Departamento      Caballito
# 113699                 -0.3      Departamento           Once

# %% [markdown]
# ## PARTE A.b Vuelviendo a entrenar el modelo implementado en el sprint 1

# %%
# Entrenamiento del arbol de desiciones del modelo propuesto con hyperparameter deñ Spr1nt 1, empezando del
# la transformacion de todos los valores missing y outliers.
#========================================================================================================================

dtree = DecisionTreeRegressor(max_depth = 9,  random_state=42)

dtree.fit(X_train_get, y_train)

y_Train_Pred_Arbol = dtree.predict(X_train_get)
y_Test_Pred_Arbol  = dtree.predict(X_test_get)

#y_Train_Pred_Arbol=y_Train_Pred_Arbol.reshape(50272,1)
#y_Test_Pred_Arbol=y_Test_Pred_Arbol.reshape(21546,1)

# para entender los datos debemos quitar la cifra dada la cual esta elevada al cuadrado, por tal motivo hacemos rmse 
# sacamos raiz cuadra = .sqrt

Arbol_rmse_train = np.sqrt(mean_squared_error(y_train, y_Train_Pred_Arbol))
Arbol_rmse_test = np.sqrt(mean_squared_error(y_test, y_Test_Pred_Arbol))

# imprimimos el error cuadratico en test y train en arboles de desiciones y tambien la exactitud de nuestro modelo.
print('Arbol de decisión la Raíz del error cuadrático medio en Train:', int(Arbol_rmse_train))
print('Arbol de decisión la Raíz del error cuadrático medio en Test:', int(Arbol_rmse_test))
print('precision score del modelo Arbol de desiciones :', int(dtree.score(X_test_get, y_test)*100),'%')
print()
print('El error absoluto medio :', int(mean_absolute_error(y_test, y_Test_Pred_Arbol)))
# Out:
# Arbol de decisión la Raíz del error cuadrático medio en Train: 42960
# Arbol de decisión la Raíz del error cuadrático medio en Test: 46401
# precision score del modelo Arbol de desiciones : 79 %
#
# El error absoluto medio : 31475

# %% [markdown]
# # <div align="center">Primer logro, ya tenemos un modelo que se ve un 309% mejor en entrenamiento y 339% mejor en testeo que el propuesto en el Sprint 1</div>
# <div align="center">
# <img src="https://image.freepik.com/foto-gratis/hombre-cubos-madera-mesa-concepto-gestion_155003-10339.jpg" alt="drawing" style="width:700px;height: 400px"/></div>
#
# #### Las valores hablan por si solos, el ajuste en Test Vs train en del 93% nuestro nuevo modelo tiene un ajuste muy bueno.

# %%
# hacemos un instograma para graficar nuestro modelo de Arboles de desicion 
#===================================================================================================

plt.figure(figsize=(8,4))
plt.subplot(1,2,1)
sns.histplot( y_train - y_Train_Pred_Arbol,  bins = 20, label = 'train', kde=True, stat="density", linewidth=0, color = "r")
sns.histplot(y_test - y_Test_Pred_Arbol, bins = 20, label = 'test', kde=True, stat="density", linewidth=0, color = "b" )
plt.xlabel('errores')
plt.legend()

# hacemos un .plot  para graficar nuestro modelo de Arboles de desicion como es su aproximacion de prediccion 
ax = plt.subplot(1,2,2)
ax.scatter(y_test, y_Test_Pred_Arbol, s = 2)

lims = [
    np.min([ax.get_xlim(), ax.get_ylim()]),
    np.max([ax.get_xlim(), ax.get_ylim()]),
    ]
ax.plot(lims, lims, 'k-', alpha= 0.75, zorder= 0)
plt.xlabel('y Test')
plt.ylabel('y predic(trt)')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## <div align="center">La distribuccion del error, es muy bueno como tambien la distribucion de los datos VS la ecuacion de la recta </div>
# <div align="center">
# <img src="https://image.freepik.com/foto-gratis/robots-que-clasifican-forma-eficiente-cientos-paquetes-hora-representacion-3d_41470-3492.jpg" alt="drawing" style="width:700px;height: 400px"/></div>
#
# #### Justifica que los datos fueron mejor seleccionados, como también la estrategia para el manejo de datos atípicos fue muy asertiva para nuestro nuevo modelo.

# %% [markdown]
# # <div align="center">PARTE B.c. - Modelos Avanzados </div>
#
# ## <div align="center">1B Creando un nuevo modelo </div>
# <div align="center">
# <img src="https://image.freepik.com/foto-gratis/hermosa-panoramica-montanas-acantilados-rocosos-niebla-natural_181624-7009.jpg" alt="drawing" style="width:700px;height: 400px"/></div>
#
# Se ajusta un primer modelo de regresión lineal con regularización ridge para predecir el precio de la vivienda en función de todos los predictores disponibles.
#  Todos los argumentos de sklearn.linear_model.Ridge se dejan por defecto.
# Es importante tener en cuenta que, cuando un modelo de regresión lineal incluye regularización en los coeficientes (ridge, lasso, elasticnet), deben estandarizarse los predictores. Para asegurar que el preprocesado se realiza únicamente con los datos de entrenamiento, se combinan las transformaciones y el entrenamiento en un mismo pipeline.

# %% [markdown]
# #### Un poco de Pipeline combinado con One Hot Encoder para que todos nuestros datos queden bien procesados.

# %%
# Preprocedado
# ==============================================================================

# Identificación de columnas numéricas y categóricas
numeric_cols = X_train.select_dtypes(include=['float64', 'int']).columns.to_list()
cat_cols = X_train.select_dtypes(include=['object', 'category']).columns.to_list()


# Transformaciones para las variables numéricas
numeric_transformer = Pipeline( steps=[('scaler', StandardScaler())] )

# Transformaciones para las variables categóricas
categorical_transformer = Pipeline(  steps=[('onehot', OneHotEncoder(handle_unknown='ignore'))]  )
                           
preprocessor = ColumnTransformer(transformers=[ ('numeric', numeric_transformer, numeric_cols),
                        ('cat', categorical_transformer, cat_cols)],remainder='drop')

# passthrough = remainder
# Pipeline
# ==============================================================================

# Se combinan los pasos de preprocesado y el modelo en un mismo pipeline
pipe = Pipeline([('preprocessing', preprocessor), ('modelo', Ridge())])


# Train
# ==============================================================================
# Se asigna el resultado a _ para que no se imprima por pantalla

# %% [markdown]
# ## " 0 " es el mejor dato perdido

# %%
pipe = Pipeline([('modelo', Ridge())])
X_train_get.isna().sum()
# Out:
# Latitud                    0
# Longitud                   0
# Cuartos                    0
# Habitaciones               0
# Superficie_total           0
#                           ..
# Barrio_Villa Riachuelo     0
# Barrio_Villa Santa Rita    0
# Barrio_Villa Soldati       0
# Barrio_Villa Urquiza       0
# Barrio_Villa del Parque    0
# Length: 67, dtype: int64

# %%
# entramiento y Score de nuestro modelo regresor de crestas
#==============================================================================


_ = pipe.fit(X=X_train_get, y=y_train)

y_Train_pred_Pipe = pipe.predict(X_train_get)
y_Test_Pred_Pipe  = pipe.predict(X_test_get)

#para entender los datos debemos quitar la cifra dada la cual esta elevada al cuadrado, por tal motivo hacemos rmse 
# sacamos raiz cuadra = .sqrt

Pipe_rmse_train = np.sqrt(mean_squared_error(y_train,y_Train_pred_Pipe))
Pipe_rmse_test = np.sqrt(mean_squared_error(y_test, y_Test_Pred_Pipe))


print('la Raíz del error cuadrático medio en Train De la Regresión de crestas  :', int(Pipe_rmse_train ))
print('la Raíz del error cuadrático medio en Test  De la Regresión de crestas :', int(Pipe_rmse_test))
print('Porcentaje de aproximacion de Score de los datos Rcuadrado:',int(pipe.score(X_test_get, y_test)*100), '%')
print('Error absoluto medio :',int(mean_absolute_error(y_test, y_Test_Pred_Pipe)))
# Out:
# la Raíz del error cuadrático medio en Train De la Regresión de crestas  : 49567
# la Raíz del error cuadrático medio en Test  De la Regresión de crestas : 50447
# Porcentaje de aproximacion de Score de los datos Rcuadrado: 75 %
# Error absoluto medio : 35715

# %% [markdown]
# ## Validación Cruzada
#
# La finalidad última de un modelo, es predecir la variable respuesta, en observaciones futuras o en observaciones que el modelo no ha "visto" antes. El error mostrado por defecto tras entrenar un modelo suele ser el error de entrenamiento, el error que comete el modelo al predecir las observaciones que ya ha "visto". Si bien estos errores son útiles para entender cómo está aprendiendo el modelo (estudio de residuos), no es una estimación realista de cómo se comporta el modelo ante nuevas observaciones (el error de entrenamiento suele ser demasiado optimista). Para conseguir una estimación más certera, y antes de recurrir al conjunto de test, se pueden emplear estrategias de validación basadas en resampling.
#
# Todas ellas reciben como primer argumento un estimator que puede ser directamente un modelo o un pipeline.
#
# Las métricas de error de regresión se devuelven siempre en negativo de forma que, cuanto más próximo a 0 sea el valor, mejor el ajuste. Esto es así para que, los procesos de optimización siempre sean de maximización.

# %%
# Validación cruzada en Ridge()
# ==============================================================================

cv_scores = cross_val_score(
                estimator = pipe,
                X         = X_train_get,
                y         = y_train,
                scoring   = 'neg_root_mean_squared_error',
                cv        = 5
             )

print(f"Métricas validación cruzada: {cv_scores.astype(int)}")
print(f"Média métricas de validación cruzada: {int(cv_scores.mean())}")
# Out:
# Métricas validación cruzada: [-49455 -49787 -50093 -49049 -49771]
# Média métricas de validación cruzada: -49631

# %% [markdown]
# # Validador cruzado repetido de K-Fold
# Utilizamos  K-Fold por el rendimiento computacional y un Balance entre bias y varianza: la principal ventaja de K-fold Repite K-Fold n veces con diferente aleatorización en cada repetición.

# %%
# Validación cruzada repetida Ridge()
# ==============================================================================

cv = RepeatedKFold(n_splits=10, n_repeats=10, random_state=42)
cv_scores = cross_val_score(
                estimator = pipe,
                X         = X_train_get,
                y         = y_train,
                scoring   = 'neg_root_mean_squared_error',
                cv        = cv
             )

print(f"Métricas de validación cruzada: {cv_scores.astype(int)}")
print("")
print(f"Média métricas de validación cruzada: {int(cv_scores.mean())}")
# Out:
# Métricas de validación cruzada: [-49781 -48562 -49572 -49200 -50281 -49429 -50226 -50700 -49582 -48983
#  -47743 -50126 -50053 -49473 -50123 -50498 -49222 -51591 -49072 -48314
#  -50122 -49443 -49333 -50915 -48040 -50413 -49555 -50044 -50555 -47796
#  -49666 -48755 -50535 -49355 -48982 -50606 -49579 -49183 -49246 -50385
#  -47846 -50129 -49464 -48944 -49197 -49779 -50290 -49060 -50631 -50885
#  -48939 -48923 -49649 -49223 -49511 -50844 -49987 -49848 -49973 -49368
#  -48846 -51415 -49766 -49100 -49527 -48474 -49942 -50149 -49230 -49823
#  -49066 -48086 -49656 -49110 -50290 -49141 -49271 -50478 -51263 -49934
#  -49460 -48833 -50158 -50064 -50538 -48907 -49341 -48208 -51385 -49397
#  -48641 -49463 -48790 -49123 -49894 -50485 -48726 -51227 -50136 -49802]
#
# Média métricas de validación cruzada: -49627

# %% [markdown]
# La función cross_validate es similar a cross_val_score pero permite estimar varias métricas a la vez, tanto para test como para train, y devuelve los resultados en un diccionario.

# %%
# Validación cruzada repetida con múltiples métricas de un  algoritmo Ridge()
# ==============================================================================

cv = RepeatedKFold(n_splits=10, n_repeats=10, random_state=42)
cv_scores = cross_validate(
                estimator = pipe,
                X         = X_train_get,
                y         = y_train,
                scoring   = ('r2', 'neg_root_mean_squared_error'),
                cv        = cv,
                return_train_score = True
            )

# Se convierte el diccionario a dataframe para facilitar la visualización
cv_scores = pd.DataFrame(cv_scores)
cv_scores
# Out:
#     fit_time  score_time  test_r2  train_r2  test_neg_root_mean_squared_error  \
# 0        0.1         0.0      0.8       0.8                          -49781.7
# 1        0.1         0.0      0.8       0.8                          -48562.7
# 2        0.1         0.0      0.8       0.8                          -49573.0
# 3        0.1         0.0      0.8       0.8                          -49200.2
# 4        0.1         0.0      0.8       0.8                          -50281.3
# ..       ...         ...      ...       ...                               ...
# 95       0.1         0.0      0.8       0.8                          -50485.9
# 96       0.1         0.0      0.8       0.8                          -48726.4
# 97       0.1         0.0      0.8       0.8                          -51227.5
# 98       0.1         0.0      0.8       0.8                          -50136.5
# 99       0.1         0.0      0.8       0.8                          -49802.4
#
# ...

# %%
# Distribución del error de validación cruzada en un algoritmo Ridge()
# ==============================================================================

fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(6, 5), sharex=True)

sns.histplot(
    data    = cv_scores['test_neg_root_mean_squared_error'],
    stat    = "count",
    kde     = True,
    line_kws= {'linewidth': 2},
    color   = "firebrick",
    alpha   = 0.3,
    ax      = axes[0]
)

axes[0].set_title('neg_root_mean_squared_error', fontsize = 7, fontweight = "bold")
axes[0].tick_params(labelsize = 6)
axes[0].set_xlabel("")
    
sns.boxplot(
    cv_scores['test_neg_root_mean_squared_error'],
    ax      = axes[1]
)
axes[1].set_title('neg_root_mean_squared_error', fontsize = 7, fontweight = "bold")
axes[1].tick_params(labelsize = 6)
axes[1].set_xlabel("")


fig.tight_layout()
plt.subplots_adjust(top=0.9)
fig.suptitle('Distribución error de validación cruzada', fontsize = 10,
             fontweight = "bold");

# %% [markdown]
# #### Observamos con la validación cruzada y la distribución de error, podríamos decir que nuestro modelo tiene distribución muy parecida a una campana gaussiana.

# %%
# Diagnóstico errores (residuos) de las predicciones de validación algoritmo cruzado Ridge()
# ==============================================================================


# Validación cruzada para las predicciones 
# ==============================================================================
cv = KFold(n_splits=5, random_state=42, shuffle=True)

cv_prediccones = cross_val_predict(
    estimator = pipe,
    X         = X_train_get,
    y         = y_train,
    cv        = cv
 )




# Gráficos
# ==============================================================================
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(9, 5))

axes[0, 0].scatter(y_train, cv_prediccones, edgecolors=(0, 0, 0), alpha = 0.4)
axes[0, 0].plot([y_train.min(), y_train.max()], [y_train.min(), y_train.max()],
                'k--', color = 'black', lw=2)
axes[0, 0].set_title('Valor predicho vs valor real', fontsize = 10, fontweight = "bold")
axes[0, 0].set_xlabel('Real')
axes[0, 0].set_ylabel('Predicción')
axes[0, 0].tick_params(labelsize = 7)

axes[0, 1].scatter(list(range(len(y_train))), y_train - cv_prediccones,
                   edgecolors=(0, 0, 0), alpha = 0.4)
axes[0, 1].axhline(y = 0, linestyle = '--', color = 'black', lw=2)
axes[0, 1].set_title('Residuos del modelo', fontsize = 10, fontweight = "bold")
axes[0, 1].set_xlabel('id')
axes[0, 1].set_ylabel('Residuo')
axes[0, 1].tick_params(labelsize = 7)

sns.histplot(
    data    = y_train - cv_prediccones,
    stat    = "density",
    kde     = True,
    line_kws= {'linewidth': 1},
    color   = "firebrick",
    alpha   = 0.3,
    ax      = axes[1, 0]
)

axes[1, 0].set_title('Distribución residuos del modelo', fontsize = 10,
                     fontweight = "bold")
axes[1, 0].set_xlabel("Residuo")
axes[1, 0].tick_params(labelsize = 7)


sm.qqplot(
    y_train - cv_prediccones,
    fit   = True,
    line  = 'q',
    ax    = axes[1, 1], 
    color = 'firebrick',
    alpha = 0.4,
    lw    = 2
)
axes[1, 1].set_title('Q-Q residuos del modelo', fontsize = 10, fontweight = "bold")
axes[1, 1].tick_params(labelsize = 7)

fig.tight_layout()
plt.subplots_adjust(top=0.9)
fig.suptitle('Diagnóstico residuos', fontsize = 12, fontweight = "bold");

# %% [markdown]
# ####  nuestro modelo tiende a equivocarse más en casas de alto costo, esta particularidad podria ser:
#     •	Como vimos en los mapas de calor las casas son las propiedades de mayor costo, pero sus datos no tienen datos correlaciónados.
# #### aunque nuestro modelo puede mejorar más es  porque cuenta con otra variable categórica la cual es barrios, esta variable aunque tiene muchas particiones podemos ver que la combinación de estas 2 categóricas, puede ofrecer una mejor distribución de los errores.

# %% [markdown]
# ## Predicción

# %% [markdown]
# ##  Grid search
#
# El modelo Ridge empleado hasta ahora tiene un hiperparámetro llamado alpha, que por defecto tiene el valor 1.0. Este hiperparámetro controla la penalización que se aplica a los coeficientes del modelo. Cuanto mayor es su valor, más restricción se impone sobre los coeficientes, reduciendo así varianza, atenuando el efecto de la correlación entre predictores y minimizando el riesgo de overfitting.
#
# Se vuelve a ajustar un modelo Ridge con diferentes valores de alpha empleando validación cruzada repetida para identificar con cuál se obtienen mejores resultados.

# %%
# Pipe: preprocesado + modelo
# ==============================================================================

# Identificación de columnas numéricas y catégoricas
numeric_cols = X_train.select_dtypes(include=['float64', 'int']).columns.to_list()
cat_cols = X_train.select_dtypes(include=['object', 'category']).columns.to_list()


# Transformaciones para las variables numéricas
numeric_transformer = Pipeline( steps=[('scaler', StandardScaler())])

# Transformaciones para las variables categóricas
categorical_transformer = Pipeline(steps=[('onehot', OneHotEncoder(handle_unknown='ignore'))])

preprocessor = ColumnTransformer( transformers=[('numeric', numeric_transformer, numeric_cols),
                        ('cat', categorical_transformer, cat_cols)], remainder='passthrough')

# Se combinan los pasos de preprocesado y el modelo en un mismo pipeline
pipe = Pipeline([('preprocessing', preprocessor), ('modelo', Ridge())])

# Grid de hiperparámetros
# ==============================================================================
param_grid = {'modelo__alpha': np.logspace(-10, 5, 10)}

# Búsqueda por validación cruzada
# ==============================================================================
grid = GridSearchCV(
        estimator  = pipe,
        param_grid = param_grid,
        scoring    = 'neg_root_mean_squared_error',
        n_jobs     = multiprocessing.cpu_count() - 1,
        cv         = RepeatedKFold(n_splits = 5, n_repeats = 5), 
        verbose    = 0,
        return_train_score = True
       )

# Se asigna el resultado a _ para que no se imprima por pantalla
_ = grid.fit(X = X_train, y = y_train)

# %%
# Resultados del grid
# ==============================================================================
resultados = pd.DataFrame(grid.cv_results_)
resultados.filter(regex = '(param.*|mean_t|std_t)')\
    .drop(columns = 'params')\
    .sort_values('mean_test_score', ascending = False)
# Out:
#   param_modelo__alpha  mean_test_score  std_test_score  mean_train_score  \
# 6                 1.0         -49672.0           425.8          -49596.5
# 3                 0.0         -49673.5           426.2          -49597.5
# 1                 0.0         -49674.3           427.2          -49597.5
# 2                 0.0         -49674.4           427.2          -49597.8
# 0                 0.0         -49674.4           427.6          -49597.8
# 4                 0.0         -49674.5           427.4          -49597.8
# 5                 0.0         -49675.0           427.5          -49596.7
# 7                46.4         -49782.5           437.0          -49717.9
# 8              2154.4         -53874.8           634.1          -53850.8
# 9            100000.0         -71818.9           880.2          -71818.2
#
#    std_train_score
# 6            109.4
# 3            108.9
# 1            108.4
# 2            108.5
# 0            108.5
# 4            108.5
# 5            108.6
# ...

# %%
# Mejores hiperparámetros
# ==============================================================================
print("-----------------------------------")
print("Mejores hiperparámetros encontrados")
print("-----------------------------------")
print(grid.best_params_, ":", grid.best_score_, grid.scoring)
# Out:
# -----------------------------------
# Mejores hiperparámetros encontrados
# -----------------------------------
# {'modelo__alpha': 1.0} : -49672.01596436274 neg_root_mean_squared_error

# %%
# Resultados del grid
# ==============================================================================
resultados = pd.DataFrame(grid.cv_results_)
resultados.filter(regex = '(param.*|mean_t|std_t)')\
    .drop(columns = 'params')\
    .sort_values('mean_test_score', ascending = False)\
    .head(1)
# Out:
#   param_modelo__alpha  mean_test_score  std_test_score  mean_train_score  \
# 6                 1.0         -49672.0           425.8          -49596.5
#
#    std_train_score
# 6            109.4

# %%
# Gráfico resultados validación cruzada para cada hiperparámetro
# ==============================================================================
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 3.84), sharey=True)

# Gráfico 1
# ------------------------------------------------------------------------------
resultados.plot('param_modelo__alpha', 'mean_train_score', ax=axes[0])
resultados.plot('param_modelo__alpha', 'mean_test_score', ax=axes[0])
axes[0].fill_between(resultados.param_modelo__alpha.astype(np.float),
                resultados['mean_train_score'] + resultados['std_train_score'],
                resultados['mean_train_score'] - resultados['std_train_score'],
                alpha=0.2)
axes[0].fill_between(resultados.param_modelo__alpha.astype(np.float),
                resultados['mean_test_score'] + resultados['std_test_score'],
                resultados['mean_test_score'] - resultados['std_test_score'],
                alpha=0.2)
axes[0].legend()
axes[0].set_xscale('log')
axes[0].set_title('Evolución del error CV')
axes[0].set_ylabel('neg_root_mean_squared_error');

# Gráfico 2
# ------------------------------------------------------------------------------
numero_splits = grid.n_splits_

resultados.plot(
    x     = 'param_modelo__alpha',
    y     = [f'split{i}_train_score' for i in range(numero_splits)],
    alpha = 0.3,
    c     = 'blue', 
    ax    = axes[1]
)

resultados.plot(
    x     = 'param_modelo__alpha',
    y     = [f'split{i}_test_score' for i in range(numero_splits)],
    alpha = 0.3,
    c     = 'red', 
    ax    = axes[1]
)

axes[1].legend(
    (axes[1].get_children()[0], axes[1].get_children()[numero_splits]),
    ('training scores', 'test_scores')
)
axes[1].set_xscale('log')
axes[1].set_title('Evolución del error CV')
axes[1].set_ylabel('neg_root_mean_squared_error');

fig.tight_layout()

# %%
best_model = grid.best_estimator_

print(f"El RMSE en datos no observados es: {np.sqrt(mean_squared_error(y_test, best_model.predict(X_test)))}")
# Out:
# El RMSE en datos no observados es: 50511.955255168796

# %% [markdown]
# ### El regresión lineal con regularización ridge seleccionado, podemos decir que tiene un desempeño esperado, Pero, comparándolo con el modelo anterior, árbol de decisiones, podríamos decir que, el modelo actual algoritmo Ridge es un modelo que tiene un RMSE con un valor más alto y tiende a equivocarse en un 116% más, en entrenamiento y un 107% más en test que el modelo anterior de Árbol de decisiones presentado en el sprint 1. aunque tiende a tener un 99% de aproximación de predicción de X_test / X_train

# %% [markdown]
# ## <div align="center">2B RandomForestRegressor </div>
# <div align="center">
# <img src="https://image.freepik.com/foto-gratis/hermosa-foto-bosque-altos-arboles-verdes_181624-20615.jpg" alt="drawing" style="width:900px;height: 400px"/></div>
#
# Así que hemos construido un modelo de bosque aleatorio para resolver nuestro problema de aprendizaje automático, en este modelo  vamos a utilizar las mismas variables categóricas, lo que hicimos en el modelo anterior fue elevar los resultados al cuadrado, y si la respuesta es 1 o 0 elevados al cuadrado no tendrían como que mucho peso.

# %%
# Hacemos un nuevo Pipeline ya que mis variables son numericas vamos a utilizar un simpleImpiuter y nuestro bosque  
# =========================================================================================
my_pipeline = make_pipeline(SimpleImputer(), RandomForestRegressor(random_state= 42))

# %%
# verificamos antes de empezar las métricas de validación cruzada como nos hablan de usar este otro modelo
# =========================================================================================
scores = cross_val_score(my_pipeline, outliers1, objetivo, scoring='neg_mean_absolute_error')

print(f"Métricas de validación cruzada: {scores.astype(int)}")
# Out:
# Métricas de validación cruzada: [-2147483648 -2147483648 -2147483648 -2147483648 -2147483648]

# %%
# Entranamiento y prediccion con un Pipeline
# =========================================================================================

my_pipeline.fit(X_train_get, y_train)

y_Train_pred_my_pipe = my_pipeline.predict(X_train_get)
y_Test_Pred_my_pipe  = my_pipeline.predict(X_test_get)


#para entender los datos debemos quitar la cifra dada la cual esta elevada al cuadrado, por tal motivo hacemos rmse 
# sacamos raiz cuadra = .sqrt
My_Pipe_rmse_train = np.sqrt(mean_squared_error(y_train,y_Train_pred_my_pipe))
My_Pipe_rmse_test = np.sqrt(mean_squared_error(y_test, y_Test_Pred_my_pipe))



# imprimimos el error cuadratico en test y train en arboles de desiciones y tambien la exactitud de nuestro modelo.



print('la Raíz del error cuadrático medio en Train De la Regresion con el algoritmo RamdomForest  :', int( My_Pipe_rmse_train))
print('la Raíz del error cuadrático medio en Test De la Regresion el algoritmo RamdomForest :', int(My_Pipe_rmse_test))
print('Porcentaje de aproximacion de Score de los datos Rcuadrado:',int(my_pipeline.score(X_test_get, y_test)*100), '%')
print('Error absoluto medio :',int(mean_absolute_error(y_test, y_Test_Pred_my_pipe)))
# Out:
# la Raíz del error cuadrático medio en Train De la Regresion con el algoritmo RamdomForest  : 11960
# la Raíz del error cuadrático medio en Test De la Regresion el algoritmo RamdomForest : 31641
# Porcentaje de aproximacion de Score de los datos Rcuadrado: 90 %
# Error absoluto medio : 18530

# %% [markdown]
# #### Nuestro modelo aprende muy bien, de hecho muestra que aprende un 414% mejor que el modelo ridge, es decir que  predice muy bien en modo entrenamiento cuando conoce los datos, pero cuando hay un dato que no conoce se equivoca, aunque podríamos decir que  menos que los otros modelos. Ya que es un 157% más preciso que el modelo Ridge y un 147% más preciso que el modelo de árbol de decisiones, pero está entrando en over fitting ya que train/test 265%.

# %% [markdown]
# ## <div align="center">Tuning del preprocesado nuestro modelo, ¡a veces obtenemos sorpresas! </div>
# <div align="center">
# <img src="https://image.freepik.com/foto-gratis/hombre-afinando-guitarra-acustica_1150-6349.jpg" alt="drawing" style="width:1000px;height: 400px"/></div>

# %%
# Validación cruzada de  RandomForestRegressor
# ==============================================================================

cv_scores_Random = cross_val_score(
        estimator = my_pipeline,
        X         = X_train_get,
        y         = y_train,
        scoring   = 'neg_root_mean_squared_error',
        cv        = 5
    )

print(f"Métricas validación cruzada: {cv_scores_Random.astype(int)}")
print(f"Média métricas de validación cruzada: {int(cv_scores_Random.mean())}")
# Out:
# Métricas validación cruzada: [-31266 -31436 -31372 -29182 -30565]
# Média métricas de validación cruzada: -30764

# %%
# Repeticcion de la Validación cruzada de RandomForestRegressor
# ==============================================================================

cv_random = RepeatedKFold(n_splits=10, n_repeats=10, random_state=42)
cv_scores_Random = cross_val_score(
                       estimator = my_pipeline,
                       X         = X_train_get,
                       y         = y_train,
                       scoring   = 'neg_root_mean_squared_error',
                        cv        = cv_random,
)

print(f"Métricas de validación cruzada: {cv_scores_Random.astype(int)}")
print("")
print(f"Média métricas de validación cruzada: {int(cv_scores_Random.mean())}")
# Out:
# Métricas de validación cruzada: [-29266 -29040 -31418 -29044 -30867 -29580 -30456 -30173 -30713 -29104
#  -28827 -30852 -30256 -29352 -29808 -30528 -29693 -31486 -29482 -29265
#  -31191 -29427 -29597 -30980 -28459 -29781 -29814 -31075 -30609 -29173
#  -30311 -30223 -30052 -29506 -29076 -29716 -29489 -30343 -28670 -31469
#  -28168 -29603 -31248 -30247 -29559 -30592 -29271 -29972 -30592 -30619
#  -30008 -28932 -29232 -31178 -30776 -29736 -30510 -29974 -29900 -28955
#  -29534 -31296 -29692 -28828 -30207 -30005 -29396 -29319 -29743 -30384
#  -30615 -29589 -30966 -29436 -29524 -28786 -29366 -31022 -30964 -30521
#  -29021 -30225 -30925 -28644 -31246 -29145 -30401 -28719 -31421 -30396
#  -29521 -30236 -30799 -30247 -30806 -30264 -29224 -30751 -29367 -29649]
#
# Média métricas de validación cruzada: -29974

# %%
 # Validación cruzada repetida con múltiples métricas RandomForestRegressor
# ==============================================================================
    
cv_random    = RepeatedKFold(n_splits=10, n_repeats=10, random_state=42)
cv_scores_random = cross_validate(
                        estimator = my_pipeline,
                        X         = X_train_get,
                        y         = y_train,
                        scoring   = ('r2', 'neg_root_mean_squared_error'),
                        cv        = cv_random,
                        return_train_score = True
)

# Se convierte el diccionario a dataframe para facilitar la visualización
cv_scores_random = pd.DataFrame(cv_scores_random)
cv_scores_random
# Out:
#     fit_time  score_time  test_r2  train_r2  test_neg_root_mean_squared_error  \
# 0       36.2         0.2      0.9       1.0                          -29266.9
# 1       35.4         0.2      0.9       1.0                          -29040.8
# 2       34.0         0.2      0.9       1.0                          -31418.7
# 3       35.2         0.2      0.9       1.0                          -29044.4
# 4       35.6         0.2      0.9       1.0                          -30867.5
# ..       ...         ...      ...       ...                               ...
# 95      39.5         0.2      0.9       1.0                          -30264.2
# 96      38.2         0.3      0.9       1.0                          -29224.2
# 97      38.3         0.2      0.9       1.0                          -30752.0
# 98      35.3         0.2      0.9       1.0                          -29367.6
# 99      34.9         0.2      0.9       1.0                          -29649.1
#
# ...

# %%
# Diagnóstico errores (residuos) de las predicciones de validación algoritmo RandomForestRegressor
# ==============================================================================


# Validación cruzada para las predicciones 
# ==============================================================================
cv = KFold(n_splits=5, random_state=42, shuffle=True)

cv_prediccones1 = cross_val_predict(
    estimator = my_pipeline,
    X         = X_train_get,
    y         = y_train,
    cv        = cv
 )




# Gráficos
# ==============================================================================
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(9, 5))

axes[0, 0].scatter(y_train, cv_prediccones1, edgecolors=(0, 0, 0), alpha = 0.4)
axes[0, 0].plot([y_train.min(), y_train.max()], [y_train.min(), y_train.max()],
                'k--', color = 'black', lw=2)
axes[0, 0].set_title('Valor predicho vs valor real', fontsize = 10, fontweight = "bold")
axes[0, 0].set_xlabel('Real')
axes[0, 0].set_ylabel('Predicción')
axes[0, 0].tick_params(labelsize = 7)

axes[0, 1].scatter(list(range(len(y_train))), y_train - cv_prediccones1,
                   edgecolors=(0, 0, 0), alpha = 0.4)
axes[0, 1].axhline(y = 0, linestyle = '--', color = 'black', lw=2)
axes[0, 1].set_title('Residuos del modelo', fontsize = 10, fontweight = "bold")
axes[0, 1].set_xlabel('id')
axes[0, 1].set_ylabel('Residuo')
axes[0, 1].tick_params(labelsize = 7)

sns.histplot(
    data    = y_train - cv_prediccones1,
    stat    = "density",
    kde     = True,
    line_kws= {'linewidth': 1},
    color   = "firebrick",
    alpha   = 0.3,
    ax      = axes[1, 0]
)

axes[1, 0].set_title('Distribución residuos del modelo', fontsize = 10,
                     fontweight = "bold")
axes[1, 0].set_xlabel("Residuo")
axes[1, 0].tick_params(labelsize = 7)


sm.qqplot(
    y_train - cv_prediccones1,
    fit   = True,
    line  = 'q',
    ax    = axes[1, 1], 
    color = 'firebrick',
    alpha = 0.4,
    lw    = 2
)
axes[1, 1].set_title('Q-Q residuos del modelo', fontsize = 10, fontweight = "bold")
axes[1, 1].tick_params(labelsize = 7)

fig.tight_layout()
plt.subplots_adjust(top=0.9)
fig.suptitle('Diagnóstico residuos RandomForestRegressor', fontsize = 12, fontweight = "bold");

# %%
# Random Search para buscar cual seria nuestro mejor Hyper parametro en RandomForestRegressor
# ==============================================================================

random_grid = {'n_estimators': [50, 80, 100, 120, 200],
               'oob_score' : [True, False],               
                'max_features': ['auto', 'sqrt'],
                'max_depth': [1, 2, 3, 5, 50, 200],
                'min_samples_split': [1, 2, 5, 10],
                'min_samples_leaf': [1, 3, 4],
                'bootstrap': [True, False],
                #'max_leaf_nodes': [2, 5, 10]
}           

        

rf = RandomForestRegressor()

rf_random = RandomizedSearchCV(estimator = rf,
                               param_distributions = random_grid,
                               scoring='neg_root_mean_squared_error',
                               n_iter = 100, 
                               cv = 5, 
                               verbose=2, 
                               random_state=42,
                               n_jobs = -1)

# %%
# Entrenenamos ndomizedSearchCV() de RandomForestRegressor
# ==============================================================================

rf_random.fit(X_train_get, y_train)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done 146 tasks      | elapsed: 10.1min
# [Parallel(n_jobs=-1)]: Done 349 tasks      | elapsed: 26.3min
# [Parallel(n_jobs=-1)]: Done 500 out of 500 | elapsed: 36.0min finished
# RandomizedSearchCV(cv=5, estimator=RandomForestRegressor(), n_iter=100,
#                    n_jobs=-1,
#                    param_distributions={'bootstrap': [True, False],
#                                         'max_depth': [1, 2, 3, 5, 50, 200],
#                                         'max_features': ['auto', 'sqrt'],
#                                         'min_samples_leaf': [1, 3, 4],
#                                         'min_samples_split': [1, 2, 5, 10],
#                                         'n_estimators': [50, 80, 100, 120, 200],
# ...

# %%
# Mejores hiperparámetros RandomForestRegressor
# ==============================================================================
print('Mejores Hiperparametros:')
rf_random.best_params_
# Out:
# Mejores Hiperparametros:
# {'oob_score': False,
#  'n_estimators': 50,
#  'min_samples_split': 2,
#  'min_samples_leaf': 1,
#  'max_features': 'sqrt',
#  'max_depth': 200,
#  'bootstrap': False}

# %%
# para ver los mejores 
#===================================================================================
print(int(rf_random.best_score_),'= combradado por', rf_random.scoring)
# Out:
# -29669 = combradado por neg_root_mean_squared_error

# %%
#  RandomForestRegressor con los mejores hiperparámetros 
# ==============================================================================

rf = RandomForestRegressor(n_estimators = 50,
                           max_depth = 200,
                           min_samples_split = 2,
                           min_samples_leaf = 1,
                           max_features = 'sqrt',
                           n_jobs = -1,
                           oob_score = True,
                           bootstrap = True,
                           random_state = 42)
rf.fit(X_train_get, y_train)

print('R^2 Training Score: {:.2f} \nOOB Score: {:.2f} \nR^2 Validation Score: {:.2f}'.format(rf.score(X_train_get, y_train), 
                                                                                             rf.oob_score_,
                                                                                             rf.score(X_test_get, y_test)))
# Out:
# R^2 Training Score: 0.99
# OOB Score: 0.92
# R^2 Validation Score: 0.91

# %%
# Resultados del rf_random de RandomForestRegressor
# ==============================================================================
resultados1 = pd.DataFrame(rf_random.cv_results_)
resultados1.filter(regex = '(param.*|mean_t|std_t)')\
            .drop(columns = 'params')\
            .sort_values('mean_test_score', ascending = False)\
            .head(1)
# Out:
#    param_oob_score param_n_estimators param_min_samples_split  \
# 39           False                 50                       2
#
#    param_min_samples_leaf param_max_features param_max_depth param_bootstrap  \
# 39                      1               sqrt             200           False
#
#     mean_test_score  std_test_score
# 39         -29669.1           618.2

# %%
# Error de test del modelo final
# ==============================================================================
modelo_final = rf_random.best_estimator_
predicciones = modelo_final.predict(X = X_test_get)
rmse_gbm = mean_squared_error(
            y_true  = y_test,
            y_pred  = predicciones,
            squared = False

)

y_Train_pred_my_rf= rf.predict(X_train_get)
My_rf_rmse_train = np.sqrt(mean_squared_error(y_train,y_Train_pred_my_rf))


print('El error (rmse) de Train es:', int( My_rf_rmse_train))
print(f"El error (rmse) de test es: {int(rmse_gbm)}")
print('precision score del modelo Bosque aleatorio Regresor :', int(rf.score(X_test_get, y_test)*100),'%')
print()
# Out:
# El error (rmse) de Train es: 12033
# El error (rmse) de test es: 29861
# precision score del modelo Bosque aleatorio Regresor : 91 %

# %% [markdown]
# # <div align="center">¡Otra manera de aprender es darse la oportunidad de hacer cambios radicales, así implique volver al principio!</div>
# <div align="center">
# <img src="https://image.freepik.com/foto-gratis/oficial-militar-tecnologia-ejercito-tableta-transparente_53876-97918.jpg" alt="drawing" style="width:700px;height: 400px"/></div>
#
# #### podemos ver muchas cosas interesantes con este nuevo modelo como:
#     - RandomizedSearchCV() es computacionalmente mejor y más rápido.
#
#     - Lo hace un modelo más fácil de implementar, y nuestro modelo trabaja ya con variables numéricas y categóricas (enDummies).
#
#     - Diferencias del costo computacional en Tonning:
#       * 5760 minutos se demoró Gridsearch, para realizar la búsqueda de los mejores hiperparámetro, lo que se traduce en un costo computacional altísimo lo que puede ser contraproducente en producción.
#       *  tan solo 25 minutos realizó RandomizedSearchCV() la misma operación anterior, lo que es ventajoso por donde se mire, por esto decidimos solo presentar RandomizedSearchCV().
#
# ### Al quitar variables de tiempo ya que dispersa mucho el dataset (genera muchas columnas con pocos aciertos en cada una) y la mejora en predicción de nuestro modelo podemos decir que
# ## ramdomforest() pasó la prueba.

# %%
fig, axes = plt.subplots(nrows=3, ncols=1, figsize=(6, 6))
sns.distplot(
   cv_scores_random,
    hist    = False,
    rug     = True,
    color   = "blue",
    kde_kws = {'shade': True, 'linewidth': 1},
    ax      = axes[0]
)
axes[0].set_title("Distribución original", fontsize = 'medium')
axes[0].set_xlabel('Precio_USD', fontsize='small') 
axes[0].tick_params(labelsize = 6)

sns.distplot(
    np.sqrt(cv_scores_random),
    hist    = False,
    rug     = True,
    color   = "blue",
    kde_kws = {'shade': True, 'linewidth': 1},
    ax      = axes[1]
)
axes[1].set_title("Transformación raíz cuadrada", fontsize = 'medium')
axes[1].set_xlabel('sqrt(precio)', fontsize='small') 
axes[1].tick_params(labelsize = 6)

sns.distplot(
    np.log(cv_scores_random),
    hist    = False,
    rug     = True,
    color   = "blue",
    kde_kws = {'shade': True, 'linewidth': 1},
    ax      = axes[2]
)
axes[2].set_title("Transformación logarítmica", fontsize = 'medium')
axes[2].set_xlabel('log(precio)', fontsize='small') 
axes[2].tick_params(labelsize = 6)

fig.tight_layout()

# %%
predicciones = my_pipeline.predict(X_test_get)

# %%
# Se crea un dataframe con las predicciones y el valor real
aa = (predicciones.astype(int)/y_test.astype(int))*100
df_predicciones = pd.DataFrame({'Barrio': X_test['Barrio'], 'Tipo_de_propiedad ':X_test['Tipo_de_propiedad'],
                                'precio' : y_test.astype(int), 'predicción' : predicciones.astype(int), 'Porcentaje %':aa.astype(int)})
df_predicciones.sample(10)
# Out:
#                Barrio Tipo_de_propiedad   precio  predicción  Porcentaje %
# 112167  Villa Urquiza       Departamento  115000      131046           113
# 18163        Recoleta       Departamento  200000      191751            95
# 141233      Caballito       Departamento  473600      479784           101
# 114129      Caballito       Departamento  240000      236540            98
# 42660         Palermo       Departamento  215000      215350           100
# 7231          Almagro       Departamento   85000       83955            98
# 22330       Caballito       Departamento  120000      116785            97
# 102223        Palermo       Departamento  280000      275248            98
# 29746        Recoleta       Departamento  190000      132065            69
# 8277        Caballito       Departamento  225000      224535            99

# %% [markdown]
# Podríamos finalizar este punto informando:
#     - El modelo Random Forest tiene el mejor desempeño y se equivoca en promedio en train  USD 12.033 VS nuestro modelo de árboles de decisiones que se equivocaría hasta +/- USD 42.960. lo que hace que su Score sea del 99% en train.
#
#     - El modelo Random Forest tiene un desempeño en test de USD 29.759 el cual es mucho mejor y se puede equivocar menos comparándolo VS el modelo Ridge() USD 49.597 o árbol de decisiones el cual se puede llegar a equivocar  un USD 46.401. Lo que hace que se Score sea del 91% en test.
#
#
#
#  -  Como podemos ver en la tabla anterior el modelo puede llegar a predecir el precio con datos que no conoce con 99% de aproximación.
#
#     - El modelo Ridge() implica más variables y mucho más tiempo en la programación, pero el gasto computacional es mínimo, y puede trabajar con mucho mas variables. Lo cual es óptimo para estos casos.
#
# ## Para este caso trabajaríamos con el modelo RandomForestRegressor(), revisaría que otra estrategia se podría implementar para disminuir el error, pero para este caso digo que es modelo muy eficiente con resultados aceptables y digno de presentar.

# %% [markdown]
# # <div align="center">PARTE C - Interpretación de modelos    </div>
# <div align="center">
# <img src="https://image.freepik.com/foto-gratis/soldado-auriculares-vr-tocando-pantalla-virtual_53876-98537.jpg" alt="drawing" style="width:700px;height: 400px"/></div>

# %% [markdown]
# # Importancia de la función RandomForestRegressor()
#
# ## ¿Qué variables son las más importantes para nuestro modelo de clasificación?
#     creo que es una pregunta que nos hacemos y durante todo este contenido, sigue rondando esa voraz pregunta, para eso buscamos la Importancia de la característica basada en la disminución media de impureza Las características importantes son proporcionadas por el atributo ajustado feature_importances_ y se calculan como la media y la desviación estándar de la acumulación de la disminución de impurezas dentro de cada árbol.

# %%
# Advertencia La importancia de las características basadas en impurezas puede ser engañosa para las características de alta cardinalidad 
## (muchos valores únicos). Consulte Importancia de la característica de permutación como alternativa a continuación.
#==================================================================================================================================================

rf.feature_importances_
# Out:
# array([1.17014291e-01, 6.68627665e-02, 8.55510026e-02, 5.84657647e-02,
#        2.28226699e-01, 9.41772311e-02, 2.21166875e-01, 1.53088818e-03,
#        8.09147585e-03, 8.71345254e-03, 2.47838115e-04, 1.49889525e-04,
#        3.43078411e-03, 3.03231078e-03, 7.99452767e-04, 3.74089436e-03,
#        1.04093161e-02, 1.26713751e-03, 3.97991525e-04, 3.00925447e-03,
#        9.54463928e-06, 4.35745123e-04, 5.31778984e-04, 3.41846333e-04,
#        9.65870760e-04, 5.86927395e-04, 7.59393185e-04, 1.73802996e-03,
#        8.23888138e-04, 2.24170717e-03, 3.31191143e-04, 4.94438731e-04,
#        6.56077227e-04, 2.37415450e-04, 2.01106876e-03, 8.68589054e-04,
#        1.61476472e-02, 2.04824623e-04, 5.09983218e-04, 5.27269336e-04,
#        3.43002805e-04, 3.23006541e-04, 9.10562341e-04, 5.24022388e-04,
#        2.20592108e-02, 1.34587741e-02, 1.07809267e-03, 7.68236800e-04,
#        9.85996207e-04, 6.22234118e-04, 5.76822441e-04, 2.11702053e-04,
# ...

# %%
# con .feature_importances_ + .argsort()  con el algoritmo inicial devolvemos una matriz ordenada
#======================================================================================================

sorted_idx = rf.feature_importances_.argsort()

fig = plt.figure(figsize = (15,20))
ax = fig.gca()

plt.barh( X_train_get.columns.values[sorted_idx], rf.feature_importances_[sorted_idx])
plt.xlabel("Random Forest Feature Importance")
plt.show();

# %% [markdown]
# ## importancia de la permutancion  .importancia_permutación
#
# ##### Como nos dice scikit learn "El estimador se requiere para ser un estimador equipada. Xpuede ser el conjunto de datos utilizado para entrenar al estimador o un conjunto de reserva. La importancia de la permutación de una característica se calcula de la siguiente manera. Primero, una métrica de referencia, definida por puntuación , se evalúa en un conjunto de datos (potencialmente diferente) definido por X."

# %%
# permitamos vamos a ver si registran cambios en la importancia  de los datos
#==================================================================================================

perm_importance = permutation_importance(rf, X_test_get, y_test)

# %%
sorted_idx = rf.feature_importances_.argsort()

fig = plt.figure(figsize = (15,20))
ax = fig.gca()

sorted_idx = perm_importance.importances_mean.argsort()
plt.barh(X_train_get.columns.values[sorted_idx], perm_importance.importances_mean[sorted_idx])
plt.xlabel("Permutation Importance")
plt.show()

# %% [markdown]
# ## ¿Qué variables fueron relevantes para el modelo para hacer una predicción?
#     * puedo decir que todas las variables son importantes, si, sé que habrá unas que cuenten mejor la historia que otras, pero sabiendo las "Escuchar", para esto utilizamos los 2 diagramas de barras horizontales de pandas .barh(), y viendo todas las variables nos ayudarán mucho más como hizo nuestro Modelo de Machine learning, para realizar la regresión . Pero sí, la ideas clasificar en predecibles y no predecibles sugeriría que:
#       * Es bien importante en las variables categóricas tanto por permutación como por impurezas, la variable “Barrio" en las cuales son importantes ["Palermo" y "Puerto madero", "Belgrado”, “Recoleta"] más que otras , y en "Tipo de propiedad",  vemos con asombro que ["PH"] ayuda más a el modelo que ["Departamento"], y  ["Casa"], es menos utilizadas.
#       * En las variables numéricas hay que decir que "superficie Total" y "superficie cubierta" son las variables más relevantes para realizar la predicción tanto por permutación como por impurezas, pero vemos que también en el ranking de las importantes podemos decir que ["Latitud", "Baños", "Longitud", "Cuartos" y "Habitaciones"] fueron muy importantes para el modelo

# %% [markdown]
# ## Cuáles no?
#
# #### Las variables de tiempo por tener otro tratamiento y que pueden ayudar a cosas que no necesitamos en el ejercicio presentado, descartamos las variables de tiempo. Para este caso. Lo mismo tratamiento para las variables "currency",	"title" y "description".
# #### También podemos decir que las variables que tienen menos relevancia, de las variables categóricas la variable en "Tipo de propiedad" ['Casa'] y en "Barrios 18 tipos de barrios por permutación y 11 por impureza.
# #### De las numericas la que menos necesaria seria es Habitaciones.

# %% [markdown]
# ## Si usaste una regresión lineal con regularización, presta atención a los parámetros (pendientes) obtenidas. Si usaste un modelo de ensamble en árboles, además de ver la importancia de cada atributo, también elige algunos árboles al azar y observa qué atributos considera importantes. ¿En qué se diferencian esos árboles? ¿Por qué? Finalmente, responde, ¿coincide con lo que esperabas a partir de tu experiencia
#
# #### Probe con varios modelos, como regresion polinomica, LogisticRegression LinearRegression, Perceptron ya que como sugieren entre mas modelos implementemos  es mucho mejor por mas aprenderiamos, pero como pudieron notar me gusto mucho trabajar con pipeline y el algoritmo Ridge o Regresión de crestas.
# #### De este algoritmo púedo decir por tener una ' regularización L2 ' es decir, agrega un factor de suma de cuadrados de coeficientes en el objetivo de optimización.
#
# #### El Objetivo es optimizara alpha= RSS + α * (suma de cuadrados de coeficientes)
# #### Aquí, α (alfa) es el parámetro que equilibra la cantidad de énfasis que se le da a minimizar la RSS frente a minimizar la suma del cuadrado de los coeficientes. α puede tomar varios valores:
#
# #### α = 0:
#     * El objetivo se vuelve el mismo que la regresión lineal simple.
#     * Obtendremos los mismos coeficientes que la regresión lineal simple.
# #### α = ∞:
#     * Los coeficientes serán cero. ¿Por qué? Debido a la ponderación infinita en el cuadrado de los coeficientes, cualquier cosa menor que cero hará que el objetivo sea infinito.
# #### 0 <α <∞:
#     * La magnitud de α decidirá la ponderación dada a las diferentes partes del objetivo.
#     * Los coeficientes estarán entre 0 y unos para la regresión lineal simple.
#
# #### Toma 'alpha' como parámetro en la inicialización. a medida que aumenta el valor de alfa, la complejidad del modelo se reduce  Aunque los valores más altos de alfa reducen el sobreajuste, los valores significativamente altos también pueden causar un desajuste (por ejemplo, alfa = 5).
#
# #### Los arboles y los bosques aleatorios, tienen muchos hyperparametro muy parecidos con un para que los diferencian pero su comportamiento es similiar.

# %% [markdown]
# ## Finalmente, responde, ¿coincide con lo que esperabas a partir de tu experiencia con este dataset?
#
# #### Si, el modelo mejoró mucho mas de 3 veces comparado con el propuesto en el sprit 1, y me ayudo aprender y conocer muchos algoritmos, la idea que he tenido, es una mezcla de algoritmos para manejar este tipo de información, ya que  los datos deben primero clasificarse por regiones ya que como vimos en el sprint pasado no tiene el mismo valor la propiedad, esta a su vez debe clasificarse,  y dependiendo de esto  que corra el modelo de regresión  más ajustado

# %% [markdown]
# ## ¿Cómo es la distribución de errores (regresión) o qué clases se confunden entre sí (clasificación)? ¿Dónde falla? ¿A qué se debe?
#
# #### los errores se ven que son mucho más en los valores altos, vemos que el modelo tiende a equivocarse más, creemos que esto podría suceder por que el modelo se está viendo afectado por los datos de casa, que, si bien no son muchos, podría estar afectando el modelo de regresión. los datos PH y Departamento se confunden entre si casi que podríamos decir que son muy parecidos, lo digo basado en las correlaciones.
#
# #### También el modelo lo pueden estar afectando la diferencia de precios para la "misma" propiedad, con características básicas en los datos numéricos similares, pero con precios muy diferente, por el tipo de barrio. El Dataset debería incluir en los datos por ejemplo el extracto socioeconómico.

# %% [markdown]
# # DESAFÍO OPCIONAL

# %%
X = outliers[['Cuartos', 'Habitaciones',  'Superficie_total',	'Baños', 'Superficie_cubierta', 'Tipo_de_propiedad', 'Precio_USD']]
y =  outliers['Precio_USD']

# %%
numerical_features = X.select_dtypes(include='number').columns.tolist()
numerical_features
categorical_feature =X.select_dtypes(exclude='number').columns.tolist()
categorical_feature
# Out:
# ['Tipo_de_propiedad']

# %%
features = ['Superficie_cubierta']
iqr_features = ['Habitaciones', 'Superficie_total', 'Baños', 'Precio_USD']

# %%
X.isna().mean()
# Out:
# Cuartos               0.0
# Habitaciones          0.0
# Superficie_total      0.0
# Baños                 0.0
# Superficie_cubierta   0.0
# Tipo_de_propiedad     0.0
# Precio_USD            0.0
# dtype: float64

# %%
fig, axes = plt.subplots(nrows=3, ncols=1, figsize=(6, 6))
sns.distplot(
   y,
    hist    = False,
    rug     = True,
    color   = "blue",
    kde_kws = {'shade': True, 'linewidth': 1},
    ax      = axes[0]
)
axes[0].set_title("Distribución original", fontsize = 'medium')
axes[0].set_xlabel('Precio_USD', fontsize='small') 
axes[0].tick_params(labelsize = 6)

sns.distplot(
    np.sqrt(y),
    hist    = False,
    rug     = True,
    color   = "blue",
    kde_kws = {'shade': True, 'linewidth': 1},
    ax      = axes[1]
)
axes[1].set_title("Transformación raíz cuadrada", fontsize = 'medium')
axes[1].set_xlabel('sqrt(precio)', fontsize='small') 
axes[1].tick_params(labelsize = 6)

sns.distplot(
    np.log(y),
    hist    = False,
    rug     = True,
    color   = "blue",
    kde_kws = {'shade': True, 'linewidth': 1},
    ax      = axes[2]
)
axes[2].set_title("Transformación logarítmica", fontsize = 'medium')
axes[2].set_xlabel('log(precio)', fontsize='small') 
axes[2].tick_params(labelsize = 6)

fig.tight_layout()

# %%
numerical_features
# Out:
# ['Cuartos',
#  'Habitaciones',
#  'Superficie_total',
#  'Baños',
#  'Superficie_cubierta',
#  'Precio_USD']

# %%
numeric_cols = X.select_dtypes(include=['float64', 'int']).columns.to_list()
cat_cols = X.select_dtypes(include=['object', 'category']).columns.to_list()

# Transformaciones para las variables numéricas
numeric_transformer = Pipeline(steps=[('imputer', SimpleImputer(strategy='median')),
                            ('scaler', StandardScaler())])

# Transformaciones para las variables categóricas
categorical_transformer = Pipeline(steps=[('imputer', SimpleImputer(strategy='most_frequent')),
                                ('onehot', OneHotEncoder(handle_unknown='ignore', sparse= False))])

preprocessor = ColumnTransformer(transformers=[('numeric', numeric_transformer, numeric_cols),
                        ('cat', categorical_transformer, cat_cols)], remainder='passthrough')

# %%
X_prep = preprocessor.fit_transform(X)

# %%
# %%time
n_clusters = np.linspace(start=6, stop=40, num=10, dtype=int)

gmms = []

gmms = [GaussianMixture(n_components=n, random_state=42).fit(X_prep) for n in n_clusters]


gmms
# Out:
# Wall time: 4min
# [GaussianMixture(n_components=6, random_state=42),
#  GaussianMixture(n_components=9, random_state=42),
#  GaussianMixture(n_components=13, random_state=42),
#  GaussianMixture(n_components=17, random_state=42),
#  GaussianMixture(n_components=21, random_state=42),
#  GaussianMixture(n_components=24, random_state=42),
#  GaussianMixture(n_components=28, random_state=42),
#  GaussianMixture(n_components=32, random_state=42),
#  GaussianMixture(n_components=36, random_state=42),
#  GaussianMixture(n_components=40, random_state=42)]

# %%
aic = [model.aic(X_prep) for model in gmms]
bic = [model.bic(X_prep) for model in gmms]

# %%
plt.plot(n_clusters, aic, label='AIC')
plt.plot(n_clusters, bic, label="BIC")
plt.legend(loc='best')
plt.title("AIC vs BIC")
plt.xlabel("N clusters")
plt.show()

# %%
gmm = GaussianMixture(n_components=35, random_state=42).fit(X_prep)

# %%
X["cluster"] = pd.Series(gmm.predict(X_prep)).apply(func=lambda x: f"cluster_{int(x + 1)}")

# %%
X.groupby(by='cluster', as_index=False).median().sort_values("cluster").style.background_gradient(cmap="Blues")
# Out:
# <style  type="text/css" >
# ...

# %% [markdown]
# #### Implementando el modelo con clouster observamos que tiene una división satisfactoria, aunque poco prometedora debida a la cantidad (34) lo cual es alto para mi parecer, todo va a depender de la estrategia que se piense implementar.

# %% [markdown]
# <div align="center">
# <img src="https://img.freepik.com/foto-gratis/pizarra-corcho-nota-agradecimiento_1232-172.jpg?size=338&ext=jpg" alt="drawing" style="width:900px;height: 400px"/></div>
#
#
# # <span style="color:blue"><div align="right">Othman Madrigal Sanchez</div></span>
# ### <span style="color:blue"><div align="right">Data Science</div></span>
# <div align="right"><img src="https://images.prismic.io/acamica%2F087942ab-8d20-4cd1-86f5-0f150ab63587_iso.png?auto=compress,format" alt="drawing" style="width:100px;height: 100px"/></div>
